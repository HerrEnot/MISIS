# %% [markdown]
# # Урок 6

# %% [markdown]
# ### 1 Обсужадем ДЗ"2"
# ### 2 Классы
# ### 3 Декораторы
# ### 4 Виртуальное окружение
# ### 5 Исключения

# %%
month = int(input())
month_spis = ["Январь", "Февраль", "Март", "Апрель", "Май", "Июнь", "Июль", "Август", "Сентрябрь", "Октябрь", "Ноябрь", "Декабрь"]
print(month_spis[month-1])

# %%
year = int(input())
if year < 0:
    print("")
else:
    if year % 400 == 0:
        print("год високосный")
    elif year % 100 == 0:
        print("год не високосный")
    elif year % 4 == 0:
        print("Год високосный")
    else:
        print("Год не високосный")

# %%
year = int(input('Введите год: '))
if (year % 400 == 0) or (year % 4 == 0):
    print(year, 'Високосный год')
else:
    print(year, 'Невисокосный год')

# %%
extensions = ['png', 'jpg', 'jpeg', 'gif', 'svg']
file_name = input('Введите название файла: ')
extension = file_name[file_name.find('.')+1:]
if extension in extensions:
    print('Расширение файла - ', extension)
else:
    print('Недопустимое расширение! Сохраните файл с другим расширением.')
# Out:
# Введите название файла: png.png
# Расширение файла -  png

# %%
extensions = ['png', 'jpg', 'jpeg', 'gif', 'svg']
file_name = input('Введите название файла: ')
extension = file_name[file_name.find('.')+1:]
print(extension)
# Out:
# Введите название файла: dfdf.dsf.2323.sdsd
# dsf.2323.sdsd

# %%
file = 'Моя диссертац.gif.gif'
extensions = ['png', 'jpg', 'jpeg', 'gif', 'svg']
e = (file[:-4:-1])[::-1]
if e in extensions:
    print('Расширение файла: ' + e)
else:
    print('Вашего расширения нет в списке')
# Out:
# Расширение файла: gif

# %%
extensions = ['png', 'jpg', 'jpeg', 'gif', 'svg']
file_name = input('Введите название файла: ')
extension = file_name[file_name.find('.')+1:]
if extension in extensions:
    print('Расширение файла - ', extension)
else:
    print('Недопустимое расширение! Сохраните файл с другим расширением.')

# %%
#Проверка расширения файла
file = input('Введите название файла с расширением: ')
extensions = ['png', 'jpg', 'jpeg', 'gif', 'svg']
file = file[::-1]
ext = file[:file.find('.')]
if ext[::-1] in extensions:
    print('Допустимое разрешение файла')
else:
    print('Недопустимое расширение файла')

# %%
# 1. Какой месяц

# import calendar

MONTH_NAMES = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

def printMonth(month):
    if (month < 1) or (month > 12):
        print("Incorrect month number")
    else:
        print(MONTH_NAMES[month-1])
#         print(calendar.month_name[month])

try:
    month = int(input("Enter month number: "))
    printMonth(month)
except ValueError:
    print("Entered value is not a number")

# %%
# 2. НОД

# import math

def gcd(x, y):
    return gcdRec(abs(x), abs(y))

def gcdRec(x, y):
    if (y == 0):
        return x
    else:
        return gcd(y, x % y)

try:
    x = int(input("Enter first number: "))
    y = int(input("Enter second number: "))
    print(gcd(x, y))
#     print(math.gcd(x, y))
except ValueError:
    print("Entered value is not a number")

# %%
# 3. Проверка расширения файла
SUPPORTED_EXTENSIONS = ['png', 'jpg', 'jpeg', 'gif', 'svg']

def isSupported(filename):
    splitted = filename.split('.')
    if (len(splitted) < 2) or (len(splitted) == 2 and splitted[0] == ""):
        return False
    else:
        extension = splitted[-1]
        return extension in SUPPORTED_EXTENSIONS
    
filename = '123.gif'
print(isSupported(filename))

# %%
MONTH_NAMES = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

def printMonth(month):
    if (month < 1) or (month > 12):
        print("Incorrect month number")
    else:
        print(MONTH_NAMES[month-1])
#         print(calendar.month_name[month])

try:
    month = int(input("Enter month number: "))
    printMonth(month)
except ValueError:
    print("Entered value is not a number")

# %%
#3 - самый простой метод
import math
a = int(input())
b = int(input())
print(math.gcd(a, b))

# %%
#3 - Наибольший общий делитель
a = int(input())
b = int(input())
while a != 0 and b != 0:
    if a >= b:
        a = a % b
    elif a <= b:
        b = b % a
print(a + b)

# %%
try:
    month=int(input('Введите номер месяца\n'))
    slovar = {
            1: 'Январь',
            2: 'Февраль',
            3: 'Март',
            4: 'Апрель',
            5: 'Май',
            6: 'Июнь',
            7: 'Июль',
            8: 'Август',
            9: 'Сентябрь',
            10: 'Октябрь',
            11: 'Ноябрь',
            12: 'Декабрь'
        }
    print(slovar[month])
except ValueError:
    print("Вы ввели не число!")

# %%
try:
    a1=int(input('Введите первую переменную\n'))
    a2=int(input('Введите вторую переменную\n'))
    if a1<a2:
        NOD = a1
    else:
        NOD = a2
    while a1%NOD!=0 or a2%NOD!=0:
    
        NOD=NOD-1
    print(NOD)
    
    
except ValueError:
    print("Вы ввели не число!")

# %%
filename=input('Введите имя файла\n')
fail = True
i=0
while i<len(filename) and fail:
    if filename[i]==".":
        fail=False
    i=i+1
if  fail!=True:
    slovar = {
        'png': 0,
        'jpg': 1,
        'jpeg': 2,
        'gif': 3,
        'svg': 4
    }
    i=len(filename)-1
    temp = 0
    fileformat = ''
    while filename[i]!=".":
        i=i-1
    i=i+1
    while i<len(filename):
        fileformat+=filename[i]
        i=i+1
    try:
        print(slovar[fileformat])
    except KeyError:
        print('Неопознанный формат\n')
else:
    print('Неопознанный формат\n')

# %% [markdown]
# ###  Классы Объектно-ориентированное программирование в Python

# %% [markdown]
# Python — это процедурно-ориентированный и одновременно объектно-ориентированный язык программирования.

# %% [markdown]
# «Процедурно-ориентированный» подразумевает наличие функций. Программист может создавать функции, которые затем используются в сторонних скриптах.

# %% [markdown]
# «Объектно-ориентированный» подразумевает наличие классов. Есть возможность создавать классы, представляющие собой прототипы для будущих объектов.

# %% [markdown]
# Синтаксис для написания нового класса:

# %%
class ClassName:
    'Краткое описание класса (необязательно)'
    # Код ...

# %% [markdown]
# Для создания класса пишется ключевое слово class, его имя и двоеточие (:). Первая строчка в теле класса описывает его. (По желанию) получить доступ к этой строке можно с помощью ClassName.__doc__

# %% [markdown]
# В теле класса допускается объявление атрибутов, методов и конструктора.

# %% [markdown]
# Атрибут:
# Атрибут — это элемент класса. Например, у прямоугольника таких 2: ширина (width) и высота (height).

# %% [markdown]
# Метод:
# Метод класса напоминает классическую функцию, но на самом деле — это функция класса. Для использования ее необходимо вызывать через объект.
# Первый параметр метода всегда self (ключевое слово, которое ссылается на сам класс).

# %% [markdown]
# Конструктор:
# Конструктор — уникальный метод класса, который называется __init__.
# Первый параметр конструктора во всех случаях self (ключевое слово, которое ссылается на сам класс).
# Конструктор нужен для создания объекта.
# Конструктор передает значения аргументов свойствам создаваемого объекта.
# В одном классе всегда только один конструктор.
# Если класс определяется не конструктором, Python предположит, что он наследует конструктор родительского класса.

# %%
class Rectangle:
    'это класс на первый класс'
    def __init__(self, width, height):
        self.width=width
        self.height=height
        
    def getHeight(self):
        return self.height
    
    def getWidth(self): 
        return self.width
    
    def getArea(self):
        return self.width * self.height

# %%
r1=Rectangle(10,5)

# %%
r2=Rectangle(20,11)

# %%
r1.getHeight()
# Out:
# 5

# %%
r1.getWidth()
# Out:
# 10

# %%
r1.getArea()
# Out:
# 50

# %% [markdown]
# Что происходит при создании объекта с помощью класса?
#
# При создании объекта класса Rectangle запускается конструктор выбранного класса, и атрибутам нового объекта передаются значения аргументов. Как на этом изображении:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Конструктор с аргументами по умолчанию

# %% [markdown]
# В других языках программирования конструкторов может быть несколько. В Python — только один. Но этот язык разрешает задавать значение по умолчанию.
#
# Все требуемые аргументы нужно указывать до аргументов со значениями по умолчанию.

# %%
class Person:
    def __init__(self, name, age=1, gender='Male'):
        self.name = name
        self.age = age
        self.gender = gender
    
    def showInfo(self):
        print('Имя',self.name)
        print('Возраст',self.age)
        print('Пол',self.gender)

# %%
yaKrevedko= Person('Daniel', 30, 'Male')

# %%
yaKrevedko.showInfo()
# Out:
# Имя Daniel
# Возраст 30
# Пол Male

# %%
somebody=Person('blahblah', 23, 'FeMale')

# %%
somebody.showInfo()
# Out:
# Имя blahblah
# Возраст 23
# Пол FeMale

# %%
somebody2=Person( 23, 'FeMale')

# %%
somebody2.showInfo()
# Out:
# Имя 23
# Возраст FeMale
# Пол Male

# %%
print(somebody2)
# Out:
# <__main__.Person object at 0x7f5bd76297f0>

# %%
somebody3=Person('blahblah')

# %%
somebody4=Person('blahblah', 'FeMale')

# %%
somebody3.showInfo()
# Out:
# Имя blahblah
# Возраст 1
# Пол Male

# %%
somebody4.showInfo()
# Out:
# Имя blahblah
# Возраст FeMale
# Пол Male

# %% [markdown]
# Резюме

# %% [markdown]
# класс - это инструкция, по которой собирается конкретный объект
# экземпляр - это конкретный объект
# а метод - это функция, присущая конкретному классу объектов.

# %% [markdown]
# метод __init__(), как и другие методы класса должен принимать как минимум 1 аргумент self
# к аргументам объекта можно обращаться из метода как аргументам self (например, self.arg)
# Если аргумент создаётся конструктором __init__, то его не нужно описывать в классе как отдельную переменную

# %% [markdown]
# Если для конструктора __init__ мы зададим какие-то аргументы кроме self, то их можно будет передать в конструктор при создании экземпляра объекта, и сразу записать в аргументы, если необходимо.

# %% [markdown]
# класс - это тоже объект.

# %% [markdown]
# #### Наследование

# %% [markdown]
# Идея в том, чтобы хранить в классе только необходимые для него объекты и атрибуты.
# И структурировать, объединить в иерархию объекты.
# Обычно это иллюстрируется на примерах животных: кошечки, собачки, кролики и т.п.
# Есть класс животные, он имеет
# атрибуты: число ног, имя, возраст.
# методы: геттеры и сеттеры
#
# Теперь создадим класс кошки. Кошки - тоже животные. Поэтому все атрибуты и методы класса животные им тоже присущи. Но кроме этого, у них могут быть свои:
# атрибуты: имя и т.п.
# методы: "говорение" (мяу) и т.п.
#
# Чтобы не дублировать код, класс кошки наследуется от класса животные.
#
# Наследник получает все методы и атрибуты родителя, а так же может некоторые из них переопределить (например, если мы сделаем класс "птицы" наследником класса "животные", то, вероятно, ограничение на число ног изменится с 4 до 2), а так же задать собственные атрибуты и методы.

# %% [markdown]
# https://xn--80ahcjeib4ac4d.xn--p1ai/information/python_object_oriented_programming_oop/

# %% [markdown]
# Для наших целей классы это такая штука в которую можно спрятать какую-то логику, причём так чтобы это.

# %% [markdown]
# Вообще, все ваши классы лучше наследовать от общего типа object. Но так как мы пока даже не обсудили, что такое наследование, то давайте просто запомним что классы лучше определять вот так:

# %%
class MyClass(object):
    ...

# %% [markdown]
# При этом класс это определение некоторых принципов работы определённой коллекции операций и данных. Можно просто воспринимать класс, а точнее его конкретные экземпляры как такой хитрый контейнер. Типа такого:

# %%
class MyClass(object):
    pass

a = MyClass()
a.name = 'Имя'
a.surname = 'Фамилия'
a.middle_name = 'Отчество'

print(a.name, a.surname, a.middle_name)
# Out:
# Имя Фамилия Отчество

# %% [markdown]
# Выше мы создали объект a класса MyClass и у него задали три поля name, surname и middle_name. При этом, если мы создадим ещё один объект класса MyClass, этих полей у него не будет — они будут только у объекта a. Если мы хотим, чтобы у класса были сразу как-то инициированы какие-то поля, то эти операции надо засунуть в конструктор:

# %%
class MyClass(object):
    def __init__(self):  # эта функция вызывается когда мы пишем MyClass()
        self.name = 'Имя'
        self.surname = 'Фамилия'
        self.middle_name = 'Отчество'
        
    def __str__(self):
        return "%s %s. %s" % (
            self.name, self.middle_name[0], self.surname
        )
    
    def rename(sosisochka, newname):
        sosisochka.name = newname

# %%
a = MyClass()
print(a)
# Out:
# Имя О. Фамилия

# %% [markdown]
# «Как можно легко видеть», функция __str__ вызывается, когда мы объект кастуем к строке, либо неявно через print либо через str(a), f"{a}" или "%s" % a .

# %%
b = MyClass()
b.surname = "Онегин"
print(b)
# Out:
# Имя О. Онегин

# %%
b.rename("Евгений")
print(b)
# Out:
# Евгений О. Онегин

# %% [markdown]
# Вот ещё один, чуть более навороченный пример класса с особым композитным полем fullname, которое имеет индивидуальный сеттер, что позволяет хитро задавать сразу три поля объекта одной операцией.

# %%
class MyClass(object):
    def __init__(self,
                 name='unknown',
                 surname='unknown',
                 middle_name='unknown'
    ):
        self.name = name
        self.surname = surname
        self.middle_name = middle_name
        
    def __str__(self):
        return self.fullname
    
    def fullname_prosto_tak(self):
        return "AAAA %s %s. %s" % (
            self.name.title(),
            self.middle_name.title()[0],
            self.surname.title()
        )
    
    @property
    def fullname(self):
        return "%s %s. %s" % (
            self.name.title(),
            self.middle_name.title()[0],
            self.surname.title()
        )
    
    @fullname.setter
    def fullname(self, value):
        self.name, self.middle_name, self.surname = value.split(' ', 2)

# %%
a = MyClass()
a.fullname
# Out:
# 'Unknown U. Unknown'

# %%
a = MyClass()
print(a)
a.fullname = "Воробьев Даниил Анатольевич"
print(a)
print(a.surname)
# Out:
# Unknown U. Unknown
# Воробьев Д. Анатольевич
# Анатольевич

# %% [markdown]
# У класса могут быть специальные непривязанные к конкретным инстансам методы, которые помечаются как @classmethod

# %%
class MyClass(object):
    _secret = None
    
    @classmethod
    def hello(cls):
        return "Дратути"
    
    @classmethod
    def init_with_secret(cls, secret):
        s = MyClass()
        s._secret = secret
        return s
    
    def __str__(self):
        return f'{self.hello()}. Секрет: {self._secret}'

# %%
x = MyClass.init_with_secret(4205)
print(x)
# Out:
# Дратути. Секрет: 4205

# %% [markdown]
# А, да, и обратите внимание что первый аргумент в методах это всегда self, а у classmethods это cls. Это, собственно, текущий объект. Ничто не мешает называть эти первые позиционные аргументы по-другому, но хорошим тоном считается давать им именно такие названия. Считайте это особенностью языка.

# %% [markdown]
# А вообще, вот эти все конструкции с символом собачки над определениями функций называются декораторами, и их можно использовать, чтобы менять поведение функции. По сути, когда вы видите конструкцию

# %%
@mydecorator
def myfunction(a, b, c):
    ...

# %% [markdown]
# То надо понимать что в этом месте результат вызова функции myfunction будет использован как-то декоратором @mydecorator. Вообще декораторы это паттерн аспектно-ориентированного программирования и их, конечно, можно (и часто нужно) писать свои. Правда выглядит немного замороченно:

# %%
def my_decorator(f):
    def inner_decorator(*args, **kw):
        print("-- ENTER --")
        f(*args, **kw)
        print("-- EXIT --")
    return inner_decorator

def my_second_decorator(f):
    def inner_deco(*args, **kw):
        print(" ENTER ".center(11, "*"))
        f(*args, **kw)
        print(" EXIT ".center(11, "*"))
    return inner_deco

@my_decorator
@my_second_decorator
def hello():
    print("Hello there")
    
hello()

# %% [markdown]
# А если хочется совсем заморочиться, то можно написать вообще класс, объекты которого будут декораторами с какими-то дополнительно определёнными полями, влияющими на поведение. Типа такого:

# %%
# Class Decorator
class MyDecorator(object):
    def __init__(self, before, after):
        self.before = before
        self.after = after
        
    def __call__(self, f):
        def inner_f(*args, **kw):
            print(self.before.center(11, "*"))
            f(*args, **kw)
            print(self.after.center(11, "*"))
        return inner_f
    
mydecoratorobject = MyDecorator('Hello', 'Goodbye')

@mydecoratorobject
def f():
    print('Inside Function')
    
f()
    
print('-----')
    
@mydecoratorobject
@MyDecorator('Что-то', 'Другое')
def g():
    print('Inside Another Function')

g()
# Out:
# ***Hello***
# Inside Function
# **Goodbye**
# -----
# ***Hello***
# ***Что-то**
# Inside Another Function
# ***Другое**
# **Goodbye**

# %% [markdown]
# А вообще, декораторы бывают ещё и на классы... Но это совсем уже чёрная магия.

# %% [markdown]
# # Еще раз посмотрим на классы

# %%
class User:
  pass

# %%
user1=User()

# %%
user1.dva='два'
user1.tri='Четыре'

# %%
print(user1.dva)
# Out:
# два

# %%
print(user1.dva + user1.tri)
# Out:
# дваЧетыре

# %%
user1.car = 'Lotus'

# %%
user2=User()

# %%
user2.car
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-215-ab562a352071> in <module>
# ----> 1 user2.car
#
# AttributeError: 'User' object has no attribute 'car'

# %%
class Sotrudnik:
     zarplata = 50000
     def adder(razmer_premii):
             return razmer_premii + Sotrudnik.zarplata

# %%
Sotrudnik.zarplata
# Out:
# 50000

# %%
Sotrudnik.adder(2)
# Out:
# 50002

# %%
Petya=Sotrudnik()

# %%
Petya.zarplata
# Out:
# 50000

# %% [markdown]
# Класс создает объекты, которые в определенном смысле являются его наследниками. Это значит, что если у объекта нет собственного поля n, то интерпретатор ищет его уровнем выше, то есть в классе. Таким образом, если мы присваиваем объекту поле с таким же именем как в классе, то оно перекрывает, т. е. переопределяет, поле класса:

# %%
Petya.zarplata=60000

# %%
Petya.zarplata
# Out:
# 60000

# %%
Petya.adder(3434,5000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-241-da39f56359f1> in <module>
# ----> 1 Petya.adder(3434,5000)
#
# TypeError: adder() takes 1 positional argument but 3 were given

# %% [markdown]
# Ищу атрибут adder() у объекта Petya. Не нахожу.
#
# Тогда иду искать в класс Sotrudnik, так как он создал объект Petya.
#
# Здесь нахожу искомый метод. Передаю ему объект, к которому этот метод надо применить, и аргумент, указанный в скобках.

# %%
Sotrudnik.adder(100) преобразуется в выражение Sotrudnik.adder(Petya, 100)

# %%
class Sotrudnik:
     zarplata = 50000
     def adder(self, razmer_premii):
             return razmer_premii + self.zarplata

# %% [markdown]
# Важное отличие от обычной функции у методов класса — их первый аргумент — это всегда носитель тайного знания, содержащий объект, с которым сейчас будут осуществляться манипуляции. По договоренности, вы всегда должны называть его self, хотя никто принуждать к этому не будет, и, если вы назовете его по-другому, код продолжит работать.

# %%
Petya.adder(5000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-247-5e6ae36879bc> in <module>
# ----> 1 Petya.adder(5000)
#
# TypeError: adder() takes 1 positional argument but 2 were given

# %%
Petya=Sotrudnik()

# %%
Petya.zarplata
# Out:
# 50000

# %%
Petya.adder(5000)
# Out:
# 55000

# %%
Petya.zarplata=60000

# %%
Vasya=Sotrudnik()

# %%
Vasya.zarplata
# Out:
# 50000

# %%
Vasya.zarplata is Sotrudnik.zarplata
# Out:
# True

# %%
Petya.zarplata is Sotrudnik.zarplata
# Out:
# False

# %% [markdown]
# # Магические методы

# %%
class Sotrudnik:
    
    def __init__(self):
        print("У нас новый сотрудник на начальной должности!")
        self.vacancy = 'раб' 
    zarplata = 50000
    
    def adder(self, razmer_premii):
        return razmer_premii + self.zarplata

# %%
Igor=Sotrudnik()
# Out:
# У нас новый сотрудник на начальной должности!

# %%
Igor()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-260-de9c29bfa397> in <module>
# ----> 1 Igor()
#
# TypeError: 'Sotrudnik' object is not callable

# %%
class Sotrudnik:
    
    def __init__(self):
        print("У нас новый сотрудник на начальной должности!")
        self.vacancy = 'раб' 
        self.zarplata = 50000
        
    def adder(self, razmer_premii):
        return razmer_premii + self.zarplata

# %%
print(Igor.adder(500), Igor.vacancy)
# Out:
# 50500 раб

# %%
class Sotrudnik:
    
    def __init__(self,zarplata=50000, vacancy='раб' ):
        print("У нас новый сотрудник на должности")
        self.vacancy = vacancy
        self.zarplata = zarplata
        print(self.vacancy)
    def adder(self, razmer_premii):
        return razmer_premii + self.zarplata
    
    def propusk_activen(self):
        return True
    
    def __str__(self):
        return f"Карточка сотрудника: Должность: {self.vacancy}, Зарплата: {self.zarplata}, Вход разрешен - {self.propusk_activen()}"

# %%
Leonid=Sotrudnik(zarplata=1000000000, vacancy='Царь')
# Out:
# У нас новый сотрудник на должности
# Царь

# %%
Leonid=Sotrudnik()
# Out:
# У нас новый сотрудник на должности
# раб

# %%
Leonid.zarplata
# Out:
# 1000000000

# %%
print(Leonid)
# Out:
# Карточка сотрудника: Должность: Царь, Зарплата: 1000000000, Вход разрешен - True

# %%
class NutritionInfo:
    def __init__(self, proteins, carbs, fats):
        self.proteins = proteins
        self.carbs = carbs
        self.fats = fats
    
    def __add__(self, other):
        return NutritionInfo(self.proteins + other.proteins, self.carbs + other.carbs, self.fats + other.fats)
    
    def __str__(self):
        return f"Nutrition p {self.proteins}, c {self.carbs}, f {self.fats}"
        
    def energy(self):
        return int(self.fats * 9 + (self.carbs + self.proteins) * 4.2)

# %%
egg = NutritionInfo(1, 2, 3)
pastila = NutritionInfo(1, 2, 3)
tvorog_9 = NutritionInfo(18, 3, 9)
apple = NutritionInfo(0, 25, 0)

print(egg + pastila)
# Out:
# Nutrition p 2, c 4, f 6

# %%
breakfast = apple + tvorog_9 + pastila

# %%
breakfast.energy()
# Out:
# 313

# %%
breakfast = apple * 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-279-a94f0cd299e7> in <module>
# ----> 1 breakfast = apple * 3
#
# TypeError: unsupported operand type(s) for *: 'NutritionInfo' and 'int'

# %% [markdown]
# https://habr.com/ru/post/186608/

# %% [markdown]
# # Наследование

# %% [markdown]
# Возможность одному классу выступать в качестве наследника для другого, перенимая тем самым его свойства и методы, является важной особенностью ООП.

# %%
class User:
    def __init__(self, name, email):
        self.name = name.title()
        self.email = email.lower()

    def is_active(self):
        return False
    
    def is_superuser(self):
        return False

    def __str__(self):
        kind = "пользователь"
        if self.is_superuser():
            kind = "админ"

        return "%s %s <%s>" % (kind, self.name, self.email)

class RegularUser(User):
    pass

class SuperUser(User):
    def is_superuser(self):
        return True

###
u1 = RegularUser("vasILiy", "vasily@mail.ru")
u2 = SuperUser("LArisa", "larisa@mail.ru")
for u in (u1, u2):
    print(u)
# Out:
# пользователь Vasiliy <vasily@mail.ru>
# админ Larisa <larisa@mail.ru>

# %%
class Person:
    name = "Джон Доу"
class Worker(Person):
    zarplata = 2000
human = Worker()
print(human.name + " заработал $" + str(human.zarplata))
# Out:
# Джон Доу заработал $2000

# %% [markdown]
# Абстрактные методы

# %%
class Dog():
    def __init__(self, name):
        self.name = name
    def makeNoise(self):
        print(self.name + " Говорит: Гаф!")
class Cat():
    def __init__(self, name):
        self.name = name
    def makeNoise(self):
        print(self.name + " говорит: Мяу!")
dog = Dog("Кусака")
cat = Cat("Бутерброд")
dog.makeNoise()
cat.makeNoise()
# Out:
# Кусака Говорит: Гаф!
# Бутерброд говорит: Мяу!

# %% [markdown]
# Увлечение сложными конструкциями без явных причин называют архитектурной космонавтикой. В некоторых областях без классов не обойтись, но часто можно использовать простое правило: если вы определяете класс, у которого два метода, и один из них — конструктор __init__, можно определить одну функцию, которая делает то же самое. У нее будет много параметров, но ее будет проще читать, потому что будет меньше вложенности и отступов.

# %% [markdown]
# # DECORATORы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Декораторы — один из самых полезных инструментов в Python, однако новичкам они могут показаться непонятными.

# %% [markdown]
# Новичкам декораторы могут показаться неудобными и непонятными, потому что они выходят за рамки «обычного» процедурного программирования как в Си, где вы объявляете функции, содержащие блоки кода, и вызываете их. То же касается и объектно-ориентированного программирования, где вы определяете классы и создаёте на их основе объекты. Декораторы не принадлежат ни одной из этих парадигм и исходят из области функционального программирования.

# %% [markdown]
# Декоратор — это функция, которая позволяет обернуть другую функцию для расширения её функциональности без непосредственного изменения её кода. Вот почему декораторы можно рассматривать как практику метапрограммирования, когда программы могут работать с другими программами как со своими данными.

# %% [markdown]
# ### Как работают функции

# %% [markdown]
#  У функций Python есть определённые аспекты, с которыми мы нечасто имеем дело, и, как следствие, они забываются. Давайте проясним, что такое функции и как они представлены в Python.

# %% [markdown]
# #### Функции как процедуры

# %% [markdown]
# С этим аспектом функций мы знакомы лучше всего. Процедура — это именованная последовательность вычислительных шагов. Любую процедуру можно вызвать в любом месте программы, в том числе внутри другой процедуры или даже самой себя

# %% [markdown]
# #### Функции как объекты первого класса

# %% [markdown]
# В Python всё является объектом, а не только объекты, которые вы создаёте из классов. В этом смысле он (Python) полностью соответствует идеям объектно-ориентированного программирования. Это значит, что в Python всё это — объекты:
#
# числа;
# строки;
# классы (да, даже классы!);
# функции (то, что нас интересует).
# Тот факт, что всё является объектами, открывает перед нами множество возможностей. Мы можем сохранять функции в переменные, передавать их в качестве аргументов и возвращать из других функций. Можно даже определить одну функцию внутри другой. Иными словами, функции — это объекты первого класса.

# %% [markdown]
# функции являются объектами первого класса;
# следовательно, язык поддерживает функции высших порядков

# %% [markdown]
# Функции высших порядков — это такие функции, которые могут принимать в качестве аргументов и возвращать другие функции.

# %%
def shalom_world():
    print('shalom world!')

# %%
type(shalom_world)
# Out:
# function

# %%
privet = shalom_world

# %%
privet()
# Out:
# shalom world!

# %%
 def wrapper_function():
    def hello_world():
        print('Hello world!')
        
    hello_world()

# %%
wrapper_function()
# Out:
# Hello world!

# %%
def higher_order(func):
     print('Получена функция {} в качестве аргумента'.format(func))
     func()
     return func

higher_order(shalom_world)
# Out:
# Получена функция <function shalom_world at 0x7f5bd75e35e0> в качестве аргумента
# shalom world!
# <function __main__.shalom_world()>

# %% [markdown]
# Декоратор — это функция, которая позволяет обернуть другую функцию для расширения её функциональности без непосредственного изменения её кода.

# %%
def decorator_function(func):
    def wrapper():
        print('Функция-обёртка!')
        print('Оборачиваемая функция: {}'.format(func))
        print('Выполняем обёрнутую функцию...')
        func()
        print('Выходим из обёртки')
    return wrapper

# %% [markdown]
# Внутри decorator_function() мы определили другую функцию, обёртку, так сказать, которая обёртывает функцию-аргумент и затем изменяет её поведение. Декоратор возвращает эту обёртку.

# %%
@decorator_function
def hello_world():
     print('Hello world!')

# %%
hello_world()
# Out:
# Функция-обёртка!
# Оборачиваемая функция: <function hello_world at 0x7f5bd7533700>
# Выполняем обёрнутую функцию...
# Hello world!
# Выходим из обёртки

# %% [markdown]
#   Добавив @decorator_function перед определением функции hello_world(), мы модифицировали её поведение. Однако выражение с @ является всего лишь синтаксическим сахаром для hello_world = decorator_function(hello_world).

# %%
Иными словами, выражение @decorator_function вызывает decorator_function() с hello_world в качестве аргумента и присваивает имени hello_world возвращаемую функцию.

# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 42 kB/s  eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 1.6 MB/s eta 0:00:01
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 804 kB/s eta 0:00:01
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.8-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 456 kB/s eta 0:00:011
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2021.10.8 charset-normalizer-2.0.8 idna-3.3 requests-2.26.0 urllib3-1.26.7
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/mnt/c/ds/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
def benchmark(func):
    import time
    
    def wrapper():
        start = time.time()
        func()
        end = time.time()
        print('[*] Время выполнения: {} секунд.'.format(end-start))
    return wrapper

@benchmark
def fetch_webpage():
    import requests
    webpage = requests.get('https://misis.ru')

fetch_webpage()
# Out:
# [*] Время выполнения: 0.2209479808807373 секунд.

# %%
def fetch_webpage():
    import requests
    webpage = requests.get('https://misis.ru')
    print(webpage)

# %%
fetch_webpage()
# Out:
# <Response [200]>

# %%
def fetch_webpage():
    import requests
    webpage = requests.get('htstps://yandex.ru')
    print(webpage)

# %%
def fetch_webpage():
    import requests
    webpage = requests.get('https://yandex.ru')
    print(webpage)

# %%
def fetch_webpage():
    import requests
    webpage = requests.get('https://yandesx.ru')
    print(webpage)

# %%
def fetch_webpage():
    import requests
    webpage = requests.get('httsps://yandex.ru')
    print(webpage)

# %%
def fetch_webpage():
    import requests
    webpage = requests.get('https://yandex.ru')
    print(webpage)

# %%
def benchmark(func):
    import time
    
    def wrapper(*args, **kwargs):
        start = time.time()
        return_value = func(*args, **kwargs)
        end = time.time()
        print('[*] Время выполнения: {} секунд.'.format(end-start))
        return return_value
    return wrapper

@benchmark
def fetch_webpage(url):
    import requests
    webpage = requests.get(url)
    return webpage.text

webpage = fetch_webpage('https://bash.im')
print(webpage)
# Out:
# [*] Время выполнения: 0.4577195644378662 секунд.
#   <!doctype html>
# <html theme="light" lang="ru" data-controller="index" aside="true">
# <head>
#   <meta charset="utf-8">
#   <title>Цитатник Рунета</title>
#
#   <meta name="format-detection" content="telephone=no">
#   <meta name="apple-mobile-web-app-capable" content="yes">
#   <meta name="theme-color" content="#f5f4f2">
#   <meta name="viewport" id="view" content="width=device-width, initial-scale=1.0, minimum-scale=1.0,
#   maximum-scale=1.0" />
#   <!-- <meta name="turbolinks-root" content="/"> -->
#   <!--    -->
#   <link rel="preload" as="style" href="/3.0/bor.css?54e9492e3e49b12224457e7671125ac4">
#   <link rel="preload" as="script" href="/3.0/bor.js?54e9492e3e49b12224457e7671125ac4">
#   <!-- <link rel="preload" as="script" href="/3.0/turbolinks.js"> -->
#   <link rel="dns-prefetch" href="//yastatic.net/" crossorigin>
#   <link rel="dns-prefetch" href="//ads.adfox.ru/" crossorigin>
#   <link rel="dns-prefetch" href="//ads.yandex.ru/" crossorigin>
#   <link rel="dns-prefetch" href="//an.yandex.ru/" crossorigin>
#   <link rel="dns-prefetch" href="//static.criteo.net/" crossorigin>
#   <link rel="dns-prefetch" href="//google-analytics.com/" crossorigin>
#   <link rel="dns-prefetch" href="//cdn.jsdelivr.net/" crossorigin>
#   <link rel="dns-prefetch" href="//www.googletagservices.com/" crossorigin>
#   <link rel="stylesheet" href="/3.0/bor.css?54e9492e3e49b12224457e7671125ac4">
#   <link rel="manifest" href="/manifest.json">
#   <link rel="shortcut" href="/favicon.ico">
#   <link rel="mask-icon" href="/favicon.svg">
#   <link rel="apple-touch-icon" href="/favicon.png">
#   <link rel="apple-touch-icon" sizes="152x152" href="/favicon-152x152.png">
#   <link rel="apple-touch-icon" sizes="167x167" href="/favicon-167x167.png">
#   <link rel="apple-touch-icon" sizes="180x180" href="/favicon-180x180.png">
#   <link rel="alternate" title="Комиксы – bash.im" href="https://bash.im/rss/comics.xml" type="application/rss+xml">
#   <link rel="alternate" title="Цитатник Рунета – bash.im" href="https://bash.im/rss/" type="application/rss+xml">
#   <!-- script src="/3.0/turbolinks.js"></script> -->
#   <script>
#     var nextTheme = {
#       light: 'dark',
#       dark: 'light'
#     };
#     var colors = {
#       light:'#f5f4f2',
#       dark: '#252323'
#     };
#     var tokens = ['aside', 'theme'];
#     var meta = document.querySelector('[name="theme-color"]');
#     for (var i = 0; i < tokens.length; i++) {
#       var name = tokens[i];
#       var value = localStorage.getItem(name);
#       if (value != null) {
#         document.documentElement.setAttribute(name, value);
#         name === 'theme' && meta.setAttribute('content', colors[value]);
#       }
#     }
#   </script>
#       <script src="//yastatic.net/pcode/adfox/header-bidding.js" async data-turbolinks-eval="false"></script>
#     <script>
#   (function() {
#     var adfoxBiddersMap = {
#       'criteo': '717767',
#       'myTarget': '763128',
#       'betweenDigital': '793538',
#       'adriver': '776589',
#       'rtbhouse': '851765',
#       'otm': '1460822',
#       'getintent': '958501',
#       'buzzoola': '769160',
#       'relap': '958503',
#       'segmento': '1458193'
#     };
#     var adUnits = [
#
#       {
#           "code": "adfox_head",
#           "sizes": [
#               [
#                   300,
#                   250
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246531
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232862
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482095
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x250_head"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "gTDGOcTCrYt7Q5OpiFRy"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "899"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_head_300x250"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296766
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "0yzTtna2EwnznDg4"
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 200
#                   }
#               }
#           ]
#       },
#       {
#           "code": "adfox_side1",
#           "sizes": [
#               [
#                   300,
#                   600
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246530
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232860
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482088
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x600"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "ypJ1WBK1rI0yPuQJE35N"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "900"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_side1_300x600"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296767
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "8Ftb7M0MV61Xvb29"
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 201
#                   }
#               }
#           ]
#       },
#       {
#           "code": "adfox_top1",
#           "sizes": [
#               [
#                   300,
#                   250
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246532
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232864
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482089
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x250_top1"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "aBFw1t166fIa5eWGvXcE"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "901"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_top1_300x250"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296768
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "mz4-yusqb5VvycnJ "
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 202
#                   }
#               }
#           ]
#       },
#       {
#           "code": "adfox_top2",
#           "sizes": [
#               [
#                   300,
#                   250
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246533
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232866
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482090
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x250_top2"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "nlglJoMHIxRMkgZqmZSz"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "906"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_top2_300x250"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296769
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "8Ftb7M0MV61Xvb29"
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 203
#                   }
#               }
#           ]
#       },
#       {
#           "code": "adfox_mid1",
#           "sizes": [
#               [
#                   300,
#                   250
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246534
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232868
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482091
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x250_mid1"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "VmCaNysKK7HeuIFKn973"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "902"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_mid1_300x250"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296770
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "PcI9rW2tdmyW40VF"
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 204
#                   }
#               }
#           ]
#       },
#       {
#           "code": "adfox_mid2",
#           "sizes": [
#               [
#                   300,
#                   250
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246535
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232870
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482092
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x250_mid2"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "QmBEhJfVPlsQzwOEADdZ"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "903"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_mid2_300x250"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296771
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "kDc3CCnov0W_7Ozs"
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 205
#                   }
#               }
#           ]
#       },
#       {
#           "code": "adfox_bot1",
#           "sizes": [
#               [
#                   300,
#                   250
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246536
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232872
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482093
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x250_bot1"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "XkM4kdo4nlSDspSxdIuP"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "904"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_bot1_300x250"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296772
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "WvPz5cQFUatRkZGR"
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 206
#                   }
#               }
#           ]
#       },
#       {
#           "code": "adfox_bot2",
#           "sizes": [
#               [
#                   300,
#                   250
#               ]
#           ],
#           "bids": [
#               {
#                   "bidder": "criteo",
#                   "params": {
#                       "placementId": 1246537
#                   }
#               },
#               {
#                   "bidder": "myTarget",
#                   "params": {
#                       "placementId": 232874
#                   }
#               },
#               {
#                   "bidder": "betweenDigital",
#                   "params": {
#                       "placementId": 2482094
#                   }
#               },
#               {
#                   "bidder": "adriver",
#                   "params": {
#                       "placementId": "20:bash_300x250_bot2"
#                   }
#               },
#               {
#                   "bidder": "rtbhouse",
#                   "params": {
#                       "placementId": "IUr6KywCfb7NHXggrScq"
#                   }
#               },
#               {
#                   "bidder": "otm",
#                   "params": {
#                       "placementId": "905"
#                   }
#               },
#               {
#                   "bidder": "getintent",
#                   "params": {
#                       "placementId": "134_bash.im_desktop_adfox_bot2_300x250"
#                   }
#               },
#               {
#                   "bidder": "buzzoola",
#                   "params": {
#                       "placementId": 296773
#                   }
#               },
#               {
#                   "bidder": "relap",
#                   "params": {
#                       "placementId": "PMM8aalp8-kTQenp :"
#                   }
#               },
#               {
#                   "bidder": "segmento",
#                   "params": {
#                       "placementId": 207
#                   }
#               }
#           ]
#       }
#
#     ];
#
#     var userTimeout = 1200;
#     window.YaHeaderBiddingSettings = {
#       biddersMap: adfoxBiddersMap,
#       adUnits: adUnits,
#       timeout: userTimeout
#     };
#   })();
# </script>    <script src="//yastatic.net/pcode/adfox/loader.js" async crossorigin="anonymous" data-turbolinks-eval="false"></script>
#     <script src='//static.criteo.net/js/ld/publishertag.js' async></script>
# <script>
#   window.Criteo = window.Criteo || {};
#   window.Criteo.events = window.Criteo.events || [];
#
#   function callAdblock(adslot, zoneid, width, height) {
#     Criteo.events.push(function() {
#       Criteo.DisplayAcceptableAdIfAdblocked({
#         'zoneid': zoneid,
#         'containerid': adslot,
#         'overrideZoneFloor': false
#       });
#     });
#     window.addEventListener('message', function(e) {
#       if (e.data && e.data == zoneid) {
#         document.getElementById(adslot).style.display = 'none';
#       }
#       else return;
#     }, false);
#     var el = document.getElementById(adslot);
#     el.style.width = width + 'px';
#     el.style.height = height + 'px';
#   }
# </script>
#
#   </head>
# <body data-turbolinks-suppress-warning>
#   <header class="header">
#   <div class="header__projects">
#   <ul class="header__projects_list">
#     <li class="header__projects_item">
#       <a class="header__projects_link active" href="https://bash.im">
#         <svg class="header__projects_icon" xmlns="http://www.w3.org/2000/svg" width="16" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#           <path d="M16 0H0v16h16V0zm-1 1H1v14h14V1z"></path>
#           <path d="M3.75 3.052v-.289a15.77 15.77 0 0 0 1.726-.492c.511-.18.786-.271.826-.271a.322.322 0 0 1 .016.102v5.164a2.66 2.66 0 0 1 .657-.771 2.732 2.732 0 0 1 1.786-.636c.825 0 1.53.35 2.113 1.051.584.701.876 1.612.876 2.731 0 1.199-.379 2.225-1.137 3.078C9.855 13.573 8.86 14 7.623 14a4.76 4.76 0 0 1-1.835-.373c-.6-.249-.901-.498-.901-.746V3.917c0-.328-.045-.56-.135-.696-.09-.141-.297-.212-.623-.212l-.379.043zM6.285 12.6c.05.294.27.506.657.636.387.124.727.186 1.019.186.785 0 1.367-.296 1.743-.89.381-.594.572-1.312.572-2.154a5.17 5.17 0 0 0-.53-2.332c-.354-.718-.927-1.077-1.718-1.077-.399 0-.789.124-1.17.373-.382.243-.573.554-.573.933V12.6z"></path>
#         </svg>
#         <span class="header__projects_name">bash.im</span>
#       </a>
#     </li>
#     <li class="header__projects_item">
#       <a class="header__projects_link" href="https://ithappens.me">
#         <svg class="header__projects_icon" xmlns="http://www.w3.org/2000/svg" width="16" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#           <path d="M16 0H0v16h16V0zm-1 1H1v14h14V1z"></path>
#           <path d="M9.35 3.01l-.002-.006c-.483.923-1.25 1.72-2.186 2.337a7.957 7.957 0 0 1-.932.528 8.262 8.262 0 0 1-2.058.678 3.2 3.2 0 0 1-.077.025c-.278.078-.416.19-.416.333 0 .105.072.157.218.157h.258c.079 0 .185.014.317.04.145.026.245.072.297.137.053.052.093.177.12.373.04.183.059.38.059.589v3.416l.003.201c.003.115.009.25.017.408 0 .314-.066.556-.199.726-.119.157-.363.255-.733.294-.067 0-.172.013-.318.04-.145.026-.218.104-.218.235 0 .13.093.196.278.196.026 0 .29-.013.793-.039.516-.026.886-.04 1.11-.04l1.052.04c.33.026.608.04.833.04.159 0 .238-.073.238-.217 0-.104-.046-.17-.139-.196-.079-.026-.27-.052-.575-.078-.29-.027-.496-.118-.615-.275-.119-.17-.178-.412-.178-.726v-.255c.013-.105.02-.223.02-.354V7.351c.103-.948 1.661-1.833 2.013-1.924.16-.042.156.193.153.378l-.001.069.002-.003v5.545c0 .426.025.792.076 1.098.064.293.179.553.345.78.178.213.389.366.63.46.243.106.498.159.766.159.701 0 1.3-.26 1.797-.78a1.62 1.62 0 0 0 .268-.259c.09-.107.134-.2.134-.28l-.038-.04c-.051-.066-.09-.1-.115-.1-.166.12-.325.234-.478.34-.319.227-.618.34-.899.34-.497 0-.829-.287-.994-.86-.09-.306-.134-.805-.134-1.498V5.682c0-.307.12-.46.363-.46a5.1 5.1 0 0 1 .344.02h1.377c.191 0 .287-.113.287-.34 0-.172-.057-.26-.172-.26h-1.912c-.128 0-.21-.026-.249-.079a.968.968 0 0 1-.038-.32V2.785c0-.147-.051-.22-.153-.22-.077 0-.147.06-.21.18-.041.09-.084.179-.13.265z"></path>
#           <circle cx="5.359" cy="3.837" r="1.076"></circle>
#         </svg>
#         <span class="header__projects_name">ithappens.me</span>
#       </a>
#     </li>
#     <li class="header__projects_item">
#       <a class="header__projects_link" href="https://zadolba.li">
#         <svg class="header__projects_icon" xmlns="http://www.w3.org/2000/svg" width="16" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#           <path d="M16 0H0v16h16V0zm-1 1H1v14h14V1z"></path>
#           <path d="M16 0H0v16h16V0zm-1 1H1v14h14V1z"></path>
#           <path d="M3.93 7.678h.683V7.03c.774-.138 1.206-.642 1.206-1.302 0-.606-.366-1.038-1.128-1.182l-.138-.024V3.52c.252.054.468.174.636.36l.516-.576c-.24-.276-.594-.48-1.092-.546v-.624H3.93v.63c-.774.102-1.206.552-1.206 1.224 0 .612.36 1.068 1.128 1.206l.138.024v1.104a1.473 1.473 0 0 1-.876-.468l-.522.57c.282.354.744.588 1.338.636v.618zm-.36-3.72c0-.252.125-.408.42-.456v.906c-.295-.078-.42-.198-.42-.45zm1.41 1.83c0 .276-.139.462-.427.528v-.99c.294.072.426.192.426.462zM7.978 4.972c.594 0 .942-.426.942-1.116 0-.69-.348-1.116-.942-1.116s-.942.426-.942 1.116c0 .69.348 1.116.942 1.116zm0-.522c-.234 0-.312-.18-.312-.462v-.264c0-.282.078-.462.312-.462.234 0 .312.18.312.462v.264c0 .282-.078.462-.312.462zm1.014.162h.678l.906-1.8h-.678l-.906 1.8zM7 7h.678l.906-1.8h-.678L7 7zm2.604.072c.594 0 .942-.426.942-1.116 0-.69-.348-1.116-.942-1.116s-.942.426-.942 1.116c0 .69.348 1.116.942 1.116zm0-.522c-.234 0-.312-.18-.312-.462v-.264c0-.282.078-.462.312-.462.234 0 .312.18.312.462v.264c0 .282-.078.462-.312.462zM2.91 13h.701l.738-4.188h-.702l-.204 1.164h-.75v.66h.63l-.09.54h-.768v.66h.648L2.91 13zm1.163 0h.702l.204-1.164h.75v-.66H5.1l.09-.54h.768v-.66H5.31l.204-1.164h-.702L4.073 13zM9.448 13.102h-.63c-.828 0-1.146-.546-1.146-1.476v-.774c0-1.206.354-1.542.942-1.542.498 0 .834.234.834.912v.162h-.042c-.09-.294-.288-.438-.564-.438-.468 0-.744.402-.744 1.29s.276 1.29.744 1.29c.276 0 .474-.144.564-.438h.042v.366h.642v-2.232c0-.834-.474-1.482-1.512-1.482C7.564 8.74 7 9.352 7 11.17c0 1.686.486 2.508 1.818 2.508h.63v-.576zm-.342-1.092c-.216 0-.336-.132-.336-.576v-.396c0-.444.12-.576.336-.576.222 0 .342.138.342.354v.84c0 .216-.12.354-.342.354zM12.768 9.505l.42-3.93V2.53h-1.32v3.045l.42 3.93h.48zm-.24 3.63c.81 0 1.11-.39 1.11-.9v-.27c0-.51-.3-.9-1.11-.9s-1.11.39-1.11.9v.27c0 .51.3.9 1.11.9z"></path>
#         </svg>
#         <span class="header__projects_name">zadolba.li</span>
#       </a>
#     </li>
#   </ul>
# </div>
#   <div class="header__wrap">
#     <div class="header__title">
#       <a class="header__title_item info " href="/faq" aria-label="О проекте">
#         <svg class="header__title_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 40" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#          <path d="M20 26a6 6 0 1 0 0-12 6 6 0 0 0 0 12zm0 1a7 7 0 1 0 0-14 7 7 0 0 0 0 14zm1-10a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm0 7v-5h-2v5h2z"/>
#         </svg>
#       </a>
#       <h1 class="header__title_wrap">
#                 <span class="header__title_name">
#           Bash.im&nbsp;— Цитатник Рунета
#         </span>
#         <svg class="header__shell" viewBox="0 0 253 13" fill="none" xmlns="http://www.w3.org/2000/svg" aria-hidden="true">
#           <path d="M195.944 11.656L200.12.88h-.864l-4.176 10.776h.864z" fill="currentColor"/>
#           <path d="M.924 10h5.172v-.816h-2.4V6.508c0-.96.636-1.74 1.848-1.74h1.164v-.96h-.864c-1.296 0-1.848.744-2.088 1.56h-.06v-1.56H.924v.816h1.812v4.56H.924V10zM10.195 10.144c1.74 0 2.808-1.272 2.808-3.24 0-1.968-1.068-3.24-2.808-3.24-1.74 0-2.808 1.272-2.808 3.24 0 1.968 1.068 3.24 2.808 3.24zm0-.828c-1.068 0-1.788-.636-1.788-1.968V6.46c0-1.332.72-1.968 1.788-1.968s1.788.636 1.788 1.968v.888c0 1.332-.72 1.968-1.788 1.968zM16.79 10.144c1.74 0 2.809-1.272 2.809-3.24 0-1.968-1.068-3.24-2.808-3.24-1.74 0-2.808 1.272-2.808 3.24 0 1.968 1.068 3.24 2.808 3.24zm0-.828c-1.067 0-1.787-.636-1.787-1.968V6.46c0-1.332.72-1.968 1.788-1.968s1.788.636 1.788 1.968v.888c0 1.332-.72 1.968-1.788 1.968zM26.098 10v-.816h-2.82v-4.56h2.82v-.816h-2.82V1.624h-.924v1.62c0 .42-.156.564-.564.564h-1.536v.816h2.064v3.96c0 .828.432 1.416 1.368 1.416h2.412z" fill="#D33682"/>
#           <path d="M39.212 10l2.22-6.192h-.948L39.596 6.4l-.96 2.796h-.048l-.96-2.796-.888-2.592h-.972L37.988 10h1.224zM42.735 12.4h.96V8.992h.048c.396.756 1.044 1.152 1.908 1.152 1.512 0 2.424-1.212 2.424-3.24 0-2.028-.912-3.24-2.424-3.24-.864 0-1.512.396-1.908 1.152h-.048V3.808h-.96V12.4zm2.544-3.108c-.852 0-1.584-.444-1.584-1.272V5.788c0-.828.732-1.272 1.584-1.272 1.116 0 1.764.744 1.764 1.86v1.056c0 1.116-.648 1.86-1.764 1.86zM53.255 10h.96V3.808h-.96v4.296c0 .816-.768 1.188-1.536 1.188-.948 0-1.464-.552-1.464-1.68V3.808h-.96V7.78c0 1.5.852 2.364 2.148 2.364 1.02 0 1.5-.54 1.764-1.152h.048V10zM55.926 12.4h.96V8.992h.048c.396.756 1.044 1.152 1.908 1.152 1.512 0 2.424-1.212 2.424-3.24 0-2.028-.912-3.24-2.424-3.24-.864 0-1.512.396-1.908 1.152h-.048V3.808h-.96V12.4zm2.544-3.108c-.852 0-1.584-.444-1.584-1.272V5.788c0-.828.732-1.272 1.584-1.272 1.116 0 1.764.744 1.764 1.86v1.056c0 1.116-.648 1.86-1.764 1.86zM62.641 10h.96V7.756l1.068-.972L67.081 10h1.188l-2.868-3.768 2.568-2.424h-1.176L64.73 5.704l-1.08 1.02h-.048V1.12h-.96V10zM71.96 2.44c.553 0 .757-.264.757-.612v-.192c0-.348-.204-.612-.757-.612-.551 0-.755.264-.755.612v.192c0 .348.204.612.755.612zM69.25 10h5.28v-.816H72.44V3.808h-3.192v.816h2.232v4.56h-2.232V10zM76.708 10V5.704c0-.816.768-1.188 1.536-1.188.948 0 1.464.552 1.464 1.68V10h.96V6.028c0-1.5-.852-2.364-2.148-2.364-1.02 0-1.5.54-1.764 1.152h-.048V3.808h-.96V10h.96z" fill="#859900"/>
#           <path d="M84.128 10h.876l1.476-8.376h-.876l-.456 2.592h-1.716v.792h1.572l-.276 1.608H83v.792h1.584L84.128 10zm2.208 0h.876l.456-2.592h1.716v-.792h-1.572l.276-1.608h1.728v-.792h-1.584l.456-2.592h-.876L86.336 10zM99.815 10.144c1.236 0 2.016-.612 2.376-1.44l-.684-.468c-.312.672-.852 1.08-1.68 1.08-1.164 0-1.788-.792-1.788-1.884V6.376c0-1.092.636-1.884 1.764-1.884.768 0 1.296.372 1.524 1.008l.768-.408c-.348-.84-1.092-1.428-2.292-1.428-1.752 0-2.796 1.272-2.796 3.24 0 1.956 1.032 3.24 2.808 3.24zM109.194 10v-.84h-.864V5.752c0-1.308-.924-2.088-2.376-2.088-1.26 0-2.052.6-2.364 1.248l.648.48c.324-.564.828-.912 1.656-.912.936 0 1.476.468 1.476 1.368v.612h-1.32c-1.86 0-2.664.66-2.664 1.8 0 1.164.828 1.884 2.124 1.884 1.008 0 1.596-.444 1.86-1.152h.06c.072.576.36 1.008 1.104 1.008h.66zm-3.516-.66c-.792 0-1.284-.336-1.284-.972v-.252c0-.6.516-.936 1.656-.936h1.32V8.2c0 .636-.708 1.14-1.692 1.14zM115.501 10v-.816h-2.82v-4.56h2.82v-.816h-2.82V1.624h-.924v1.62c0 .42-.156.564-.564.564h-1.536v.816h2.064v3.96c0 .828.432 1.416 1.368 1.416h2.412zM124.324 11.656L128.5.88h-.864l-4.176 10.776h.864zM134.075 10h.96V1.12h-.96v3.696h-.048c-.396-.756-1.044-1.152-1.908-1.152-1.512 0-2.424 1.212-2.424 3.24 0 2.028.912 3.24 2.424 3.24.864 0 1.512-.396 1.908-1.152h.048V10zm-1.584-.708c-1.116 0-1.764-.744-1.764-1.86V6.376c0-1.116.648-1.86 1.764-1.86.852 0 1.584.444 1.584 1.272V8.02c0 .828-.732 1.272-1.584 1.272zM139.278 10.144c1.224 0 2.113-.6 2.485-1.428l-.708-.48c-.324.672-.949 1.08-1.777 1.08-1.164 0-1.896-.792-1.896-1.884v-.288h4.584v-.456c0-1.752-1.08-3.024-2.748-3.024-1.68 0-2.843 1.272-2.843 3.252 0 1.956 1.127 3.228 2.903 3.228zm-.06-5.688c1.02 0 1.717.744 1.717 1.836v.132h-3.553V6.34c0-1.08.78-1.884 1.836-1.884zM146.378 10l2.22-6.192h-.948l-.888 2.592-.96 2.796h-.048l-.96-2.796-.888-2.592h-.972l2.22 6.192h1.224zM150.705 11.656L154.881.88h-.864l-4.176 10.776h.864zM161.956 10v-.84h-.864V5.752c0-1.308-.924-2.088-2.376-2.088-1.26 0-2.052.6-2.364 1.248l.648.48c.324-.564.828-.912 1.656-.912.936 0 1.476.468 1.476 1.368v.612h-1.32c-1.86 0-2.664.66-2.664 1.8 0 1.164.828 1.884 2.124 1.884 1.008 0 1.596-.444 1.86-1.152h.06c.072.576.36 1.008 1.104 1.008h.66zm-3.516-.66c-.792 0-1.284-.336-1.284-.972v-.252c0-.6.516-.936 1.656-.936h1.32V8.2c0 .636-.708 1.14-1.692 1.14zM165.624 10.144c1.584 0 2.616-.708 2.616-1.932 0-1.344-1.236-1.584-2.124-1.716l-.972-.144c-.552-.084-1.092-.252-1.092-.9 0-.636.54-.984 1.512-.984 1.092 0 1.644.432 1.932.78l.624-.588c-.588-.624-1.404-.996-2.52-.996-1.44 0-2.496.612-2.496 1.848 0 1.344 1.248 1.584 2.124 1.716l.972.144c.564.084 1.092.252 1.092.9 0 .732-.684 1.068-1.644 1.068-.984 0-1.656-.348-2.244-.972l-.648.564c.648.732 1.572 1.212 2.868 1.212zM172.219 10.144c1.584 0 2.616-.708 2.616-1.932 0-1.344-1.236-1.584-2.124-1.716l-.972-.144c-.552-.084-1.092-.252-1.092-.9 0-.636.54-.984 1.512-.984 1.092 0 1.644.432 1.932.78l.624-.588c-.588-.624-1.404-.996-2.52-.996-1.44 0-2.496.612-2.496 1.848 0 1.344 1.248 1.584 2.124 1.716l.972.144c.564.084 1.092.252 1.092.9 0 .732-.684 1.068-1.644 1.068-.984 0-1.656-.348-2.244-.972l-.648.564c.648.732 1.572 1.212 2.868 1.212zM182.758 9.808l5.16-2.988v-.96l-5.16-2.988v1.02l4.26 2.412V6.4l-4.26 2.412v.996zM205.028 10h.96V1.12h-.96v3.696h-.048c-.396-.756-1.044-1.152-1.908-1.152-1.512 0-2.424 1.212-2.424 3.24 0 2.028.912 3.24 2.424 3.24.864 0 1.512-.396 1.908-1.152h.048V10zm-1.584-.708c-1.116 0-1.764-.744-1.764-1.86V6.376c0-1.116.648-1.86 1.764-1.86.852 0 1.584.444 1.584 1.272V8.02c0 .828-.732 1.272-1.584 1.272zM210.232 10.144c1.224 0 2.112-.6 2.484-1.428l-.708-.48c-.324.672-.948 1.08-1.776 1.08-1.164 0-1.896-.792-1.896-1.884v-.288h4.584v-.456c0-1.752-1.08-3.024-2.748-3.024-1.68 0-2.844 1.272-2.844 3.252 0 1.956 1.128 3.228 2.904 3.228zm-.06-5.688c1.02 0 1.716.744 1.716 1.836v.132h-3.552V6.34c0-1.08.78-1.884 1.836-1.884zM217.331 10l2.22-6.192h-.948l-.888 2.592-.96 2.796h-.048l-.96-2.796-.888-2.592h-.972l2.22 6.192h1.224zM221.658 11.656L225.834.88h-.864l-4.176 10.776h.864zM227.486 10h.96V5.704c0-.816.768 ...
#         </svg>
#               </h1>
#       <div class="header__title_item theme">
#         <svg class="header__title_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 40" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#           <g class="moon">
#             <path d="M25.295 23.652c-.175-.094-.828.06-1.11.06-3.785 0-6.854-2.931-6.854-6.644 0-.402 0-.736.126-1.12a.13.13 0 0 0 .007-.049c-.007-.12-.066-.225-.166-.104a6.683 6.683 0 0 0-.345.446c-.578.834-.945 2.006-.945 3.206 0 3.073 2.54 5.564 5.672 5.564 1.651 0 3.26-.796 3.615-1.359zm.671-1.208c-.437.183-.776.28-1.782.28-3.228 0-5.844-2.568-5.844-5.735 0-.91.113-1.473.244-1.993l.002-.007.05-.194.013-.052c.04-.155.08-.31.119-.474.034-.146-.076-.285-.228-.268a2.1 2.1 0 0 0-.467.113 2.703 2.703 0 0 0-.34.15c-1.388.73-2.733 2.817-2.733 5.183C15 23.067 17.99 26 21.68 26c2.49 0 4.468-1.222 5.114-2.83l.021-.053a3.162 3.162 0 0 0 .183-.742c.02-.17-.15-.289-.312-.228a10.53 10.53 0 0 0-.547.224l-.145.061-.027.012z"/>
#           </g>
#           <g class="sun">
#             <path d="M20 14a.5.5 0 0 1-.5-.5v-1a.5.5 0 0 1 1 0v1a.5.5 0 0 1-.5.5zM15.757 15.757a.5.5 0 0 1-.707 0l-.707-.707a.5.5 0 1 1 .707-.707l.707.707a.5.5 0 0 1 0 .707zM25.657 14.343a.5.5 0 0 1 0 .707l-.707.707a.5.5 0 1 1-.707-.707l.707-.707a.5.5 0 0 1 .707 0zM15.757 24.243a.5.5 0 0 1 0 .707l-.707.707a.5.5 0 0 1-.707-.707l.707-.707a.5.5 0 0 1 .707 0zM28 20a.5.5 0 0 1-.5.5h-1a.5.5 0 1 1 0-1h1a.5.5 0 0 1 .5.5zM14 20a.5.5 0 0 1-.5.5h-1a.5.5 0 0 1 0-1h1a.5.5 0 0 1 .5.5zM25.657 25.657a.5.5 0 0 1-.707 0l-.707-.707a.5.5 0 1 1 .707-.707l.707.707a.5.5 0 0 1 0 .707zM19.5 27.5a.5.5 0 0 0 1 0v-1a.5.5 0 1 0-1 0v1z"/>
#             <path d="M24 20a4 4 0 1 1-8 0 4 4 0 0 1 8 0zm-1 0a3 3 0 1 1-6 0 3 3 0 0 1 6 0z"/>
#           </g>
#         </svg>
#       </div>
#     </div>
#           <div class="sections mobile ">
#       <ul class="sections__list">
#       <li class="sections__item">
#         <a class="sections__link active" href="/">новые</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/best">лучшие</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/random">случайные</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/byrating">по рейтингу</a>
#       </li>
#     </ul>
#   </div>
#         <nav class="nav desktop">
#   <div class="nav__wrap">
#     <a class="nav__item about " href="/faq">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M26 19a6 6 0 1 1-12 0 6 6 0 0 1 12 0zm1 0a7 7 0 1 1-14 0 7 7 0 0 1 14 0zm-6-3a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm-1 1.875c.345 0 .625.28.625.625v4a.625.625 0 1 1-1.25 0v-4c0-.345.28-.625.625-.625z"></path>
#       </svg>
#       <span class="nav__item_name">О проекте</span>
#       </a>
#       <div class="nav__item theme">
#         <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#           <g class="moon">
#             <path d="M24.295 22.652c-.175-.094-.828.06-1.11.06-3.785 0-6.854-2.931-6.854-6.644 0-.403 0-.736.126-1.12a.13.13 0 0 0 .007-.049c-.007-.12-.066-.225-.166-.104a6.683 6.683 0 0 0-.345.446c-.578.834-.945 2.006-.945 3.206 0 3.073 2.54 5.564 5.672 5.564 1.651 0 3.26-.796 3.615-1.359zm.671-1.208c-.437.183-.776.28-1.782.28-3.228 0-5.844-2.568-5.844-5.735 0-.91.113-1.473.244-1.993l.002-.007.05-.194.013-.052c.04-.155.08-.31.119-.474.034-.146-.076-.285-.228-.268a2.1 2.1 0 0 0-.467.113 2.703 2.703 0 0 0-.34.15c-1.388.73-2.733 2.817-2.733 5.183C14 22.067 16.99 25 20.68 25c2.49 0 4.468-1.222 5.114-2.83l.021-.053a3.162 3.162 0 0 0 .183-.742c.02-.17-.15-.289-.312-.228a10.53 10.53 0 0 0-.547.224l-.145.061-.027.012z"></path>
#           </g>
#           <g class="sun">
#             <path d="M20 13a.5.5 0 0 1-.5-.5v-1a.5.5 0 0 1 1 0v1a.5.5 0 0 1-.5.5zM15.757 14.757a.5.5 0 0 1-.707 0l-.707-.707a.5.5 0 1 1 .707-.707l.707.707a.5.5 0 0 1 0 .707zM25.657 13.343a.5.5 0 0 1 0 .707l-.707.707a.5.5 0 1 1-.707-.707l.707-.707a.5.5 0 0 1 .707 0zM15.757 23.243a.5.5 0 0 1 0 .707l-.707.707a.5.5 0 0 1-.707-.707l.707-.707a.5.5 0 0 1 .707 0zM28 19a.5.5 0 0 1-.5.5h-1a.5.5 0 1 1 0-1h1a.5.5 0 0 1 .5.5zM14 19a.5.5 0 0 1-.5.5h-1a.5.5 0 0 1 0-1h1a.5.5 0 0 1 .5.5zM25.657 24.657a.5.5 0 0 1-.707 0l-.707-.707a.5.5 0 1 1 .707-.707l.707.707a.5.5 0 0 1 0 .707zM19.5 26.5a.5.5 0 0 0 1 0v-1a.5.5 0 1 0-1 0v1z"></path>
#             <path d="M24 19a4 4 0 1 1-8 0 4 4 0 0 1 8 0zm-1 0a3 3 0 1 1-6 0 3 3 0 0 1 6 0z"></path>
#           </g>
#       </svg>
#       <span class="nav__item_name">Тема</span>
#     </div>
#     <a class="nav__item active" href="/">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M27.618 18.107l-7.31-5.743L13 18.107l.618.786 1.19-.936V25.5h11v-7.543l1.192.936.618-.786zm-2.81-.935l-4.5-3.536-4.5 3.536V24.5h9v-7.328z"></path>
#       </svg>
#       <span class="nav__item_name">Новые</span>
#       <span class="nav__item_badge" data-badge="index"></span>
#     </a>
#     <a class="nav__item " href="/abyss/">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M25.849 15.448A.786.786 0 0 0 26 15c0-1.105-2.686-2-6-2s-6 .895-6 2c0 .16.056.315.162.464L18 21.642v4.727l4-2.667v-2.06l3.852-6.194h-.003zm-1.854 1.044c-1.061.316-2.46.508-3.995.508-1.534 0-2.934-.192-3.994-.508L19 21.358V24.5l2-1.333v-1.809l2.995-4.866zM24.844 15c0 .552-2.16 1-4.825 1-2.664 0-4.824-.448-4.824-1s2.16-1 4.825-1c2.664 0 4.824.448 4.824 1z"></path>
#       </svg>
#       <span class="nav__item_name">Бездна</span>
#     </a>
#     <a class="nav__item " href="/strips">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M19.5 19h-3v-1h3v1zM23.5 19h-3v-1h3v1z"></path>
#         <path d="M17 15h6l3-3v11a3 3 0 0 1-3 3h-6a3 3 0 0 1-3-3V12l3 3zm8-.586V23a2 2 0 0 1-2 2h-6a2 2 0 0 1-2-2v-8.586L16.586 16h6.828L25 14.414z"></path>
#       </svg>
#       <span class="nav__item_name">Комиксы</span>
#       <span class="nav__item_badge" data-badge="strips"></span>
#     </a>
#     <a class="nav__item " href="/search">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M25 18a5 5 0 1 1-10 0 5 5 0 0 1 10 0zm-1.31 4.731a6 6 0 1 1 .734-.679l2.446 2.608-.73.684-2.45-2.613z"></path>
#       </svg>
#       <span class="nav__item_name">Поиск</span>
#     </a>
#     <a class="nav__item " href="/add">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M19.5 18.5V24h1v-5.5H26v-1h-5.5V12h-1v5.5H14v1h5.5z"></path>
#       </svg>
#       <span class="nav__item_name">Добавить</span>
#     </a>
#   </div>
# </nav>  </div>
# </header>  <div class="columns">
#     <main class="columns__main ">
#             <div class="sections desktop top">
#       <ul class="sections__list">
#       <li class="sections__item">
#         <a class="sections__link active" href="/">новые</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/best">лучшие</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/random">случайные</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/byrating">по рейтингу</a>
#       </li>
#     </ul>
#   </div>
#
#   <div class="quote stats">
#   <div class="quote__body">
#     <span>Утверждено <b>85837</b> цитат, </span>
#     <span>сегодня <b>5</b>.</span>
#           <span>Ждут очереди в Бездне <b>137</b> цитат.</span>
#       </div>
# </div>
#
#
#   <div class="pager">
#                 <span class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M10 2L4.5 7l5.5 5M5 7h9M1 0v14" stroke="currentColor" stroke-width="1"/></svg></span><span class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><title="Свежее"/><path d="M8 2L3 7l5 5M3 7h9" stroke="currentColor" stroke-width="1"/></svg></span><input type="number" name="page" class="pager__input" pattern="[0-9]+" data-page numeric="integer" min="1" max="3434" data-path="index" value="3434" autocomplete="off"><a href="/index/3433" class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><title="Начало"/><path d="M6 2l5 5-5 5M2 7h9" stroke="currentColor" stroke-width="1"/></svg></a><a href="/index/1" class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M4 2l5 5-5 5M0 7h9M13 0v14" stroke="currentColor" stroke-width="1"/></svg></a>          </form>
#   </div>
# <section class="quotes" data-page="3434" >
#
#
#
#
# <article class="quote" data-quote="467994">
#   <div class="quote__frame">
#     <header class="quote__header">
#               <a class="quote__header_permalink" href="/quote/467994">#467994</a>
#             <div class="quote__header_date">
#         04.12.2021 в  9:11
#       </div>
#     </header>
#     <div class="quote__body">
#       xxx:<br>Сегодня в трамвае у кого-то навигатор вякнул: &quot;Через 50 метров спуститесь в подземный переход&quot;. Интересно, трамвай, спустившийся в подземный переход, считается детёнышем метропоезда?
#           </div>
#           <footer class="quote__footer">
#         <div class="quote__button dismiss" role="button" aria-label="Это баян!" tabindex="0" data-vote="[467994, 2, 0]" title="Это баян!">
#           <svg xmlns="http://www.w3.org/2000/svg" width="22" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M4 .375H.375v15.25H4v-1.25H1.625V1.625H4V.375zM12.375.5v15h1.25V.5h-1.25zm-4 15V.5h1.25v15h-1.25zM18 1.625h2.375v12.75H18v1.25h3.625V.375H18v1.25zM6 6a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm-1 5a1 1 0 1 0 0-2 1 1 0 0 0 0 2zm13-1a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm-1-3a1 1 0 1 0 0-2 1 1 0 0 0 0 2z" fill-rule="evenodd" clip-rule="evenodd"/>
#           </svg>
#         </div>
#         <div class="quote__button down" role="button" aria-label="Голосовать против этой цитаты" tabindex="0" data-vote="[467994, 1, 0]" data-swipe="1" title="Голосовать против этой цитаты">
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M.375.375H4v1.25H1.625v12.75H4v1.25H.375V.375zm5.625 7h8v1.25H6v-1.25zm10-5.75h2.375v12.75H16v1.25h3.625V.375H16v1.25z"/>
#           </svg>
#         </div>
#         <div class="quote__total" data-vote-counter>45</div>
#         <div class="quote__button up" role="button" aria-label="Голосовать за эту цитату" tabindex="0" data-vote="[467994, 0, 0]" data-swipe="0" title="Голосовать за эту цитату">
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M.375.375H4v1.25H1.625v12.75H4v1.25H.375V.375zm10.25 7V3h-1.25v4.375H5v1.25h4.375V13h1.25V8.625H15v-1.25h-4.375zM16 1.625h2.375v12.75H16v1.25h3.625V.375H16v1.25z"/>
#           </svg>
#         </div>
#         <div role="button" class="quote__button share" role="button" aria-label="Поделиться" tabindex="0" data-share='{"id": "467994", "url": "quote/467994", "title": "Цитата #467994", "description": "xxx:&lt;br&gt;Сегодня в трамвае у кого-то навигатор вякнул: &amp;quot;Через 50 метров спуститесь в подземный переход&amp;quot;. Интересно, трамвай, спустившийся в подземный переход, считается детёнышем метропоезда?"}' title="Поделиться цитатой">
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M9 .116l3.942 3.942-.884.884-2.433-2.433V12h-1.25V2.509L5.942 4.942l-.884-.884L9 .116zM1.625 9H.375v6.625h17.25V9h-1.25v5.375H1.625V9z"/>
#           </svg>
#         </div>
#
#       </footer>
#       </div>
# </article>
#
#
#
# <article class="quote" data-quote="467993">
#   <div class="quote__frame">
#     <header class="quote__header">
#               <a class="quote__header_permalink" href="/quote/467993">#467993</a>
#             <div class="quote__header_date">
#         04.12.2021 в  8:46
#       </div>
#     </header>
#     <div class="quote__body">
#       luhrasp: Все эти споры про маски и прививку - они же не только разделяют нас на лагеря, отдаляют, сеют рознь между друзьями и членами семьи. Они заставили нас забыть о чём-то действительно важном.<br><br>Чём-то значимом. В миллион раз более искреннем. Том, что на душе у каждого из нас.<br><br>luhrasp: Я о войне тех, кому душно, с теми, кому дует, конечно.
#           </div>
#           <footer class="quote__footer">
#         <div class="quote__button dismiss" role="button" aria-label="Это баян!" tabindex="0" data-vote="[467993, 2, 0]" title="Это баян!">
#           <svg xmlns="http://www.w3.org/2000/svg" width="22" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M4 .375H.375v15.25H4v-1.25H1.625V1.625H4V.375zM12.375.5v15h1.25V.5h-1.25zm-4 15V.5h1.25v15h-1.25zM18 1.625h2.375v12.75H18v1.25h3.625V.375H18v1.25zM6 6a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm-1 5a1 1 0 1 0 0-2 1 1 0 0 0 0 2zm13-1a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm-1-3a1 1 0 1 0 0-2 1 1 0 0 0 0 2z" fill-rule="evenodd" clip-rule="evenodd"/>
#           </svg>
#         </div>
#         <div class="quote__button down" role="button" aria-label="Голосовать против этой цитаты" tabindex="0" data-vote="[467993, 1, 0]" data-swipe="1" title="Голосовать против этой цитаты">
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M.375.375H4v1.25H1.625v12.75H4v1.25H.375V.375zm5.625 7h8v1.25H6v-1.25zm10-5.75h2.375v12.75H16v1.25h3.625V.375H16v1.25z"/>
#           </svg>
#         </div>
#         <div class="quote__total" data-vote-counter>171</div>
#         <div class="quote__button up" role="button" aria-label="Голосовать за эту цитату" tabindex="0" data-vote="[467993, 0, 0]" data-swipe="0" title="Голосовать за эту цитату">
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M.375.375H4v1.25H1.625v12.75H4v1.25H.375V.375zm10.25 7V3h-1.25v4.375H5v1.25h4.375V13h1.25V8.625H15v-1.25h-4.375zM16 1.625h2.375v12.75H16v1.25h3.625V.375H16v1.25z"/>
#           </svg>
#         </div>
#         <div role="button" class="quote__button share" role="button" aria-label="Поделиться" tabindex="0" data-share='{"id": "467993", "url": "quote/467993", "title": "Цитата #467993", "description": "luhrasp: Все эти споры про маски и прививку - они же не только разделяют нас на лагеря, отдаляют, сеют рознь между друзьями и членами семьи. Они заставили нас забыть о чём-то действительно важном.&lt;br&gt;&lt;br&gt;Чём-то значимом. В миллион раз более искреннем. Том, что на душе у каждого из нас.&lt;br&gt;&lt;br&gt;luhrasp: Я о войне тех, кому душно, с теми, кому дует, конечно."}' title="Поделиться цитатой">
# ...
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M.375.375H4v1.25H1.625v12.75H4v1.25H.375V.375zm5.625 7h8v1.25H6v-1.25zm10-5.75h2.375v12.75H16v1.25h3.625V.375H16v1.25z"/>
#           </svg>
#         </div>
#         <div class="quote__total" data-vote-counter>814</div>
#         <div class="quote__button up" role="button" aria-label="Голосовать за эту цитату" tabindex="0" data-vote="[467970, 0, 0]" data-swipe="0" title="Голосовать за эту цитату">
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M.375.375H4v1.25H1.625v12.75H4v1.25H.375V.375zm10.25 7V3h-1.25v4.375H5v1.25h4.375V13h1.25V8.625H15v-1.25h-4.375zM16 1.625h2.375v12.75H16v1.25h3.625V.375H16v1.25z"/>
#           </svg>
#         </div>
#         <div role="button" class="quote__button share" role="button" aria-label="Поделиться" tabindex="0" data-share='{"id": "467970", "url": "quote/467970", "title": "Цитата #467970", "description": "AAA: На прошлом месте настроил автоответы в Слаке на ключевые слова. На словосочетание &amp;quot;лучшая команда&amp;quot; выскакивало название нашей команды, фото тилида и наши командные смайлики (включая кастомные).&lt;br&gt;AAA: Все бы ни чего, только я уволился год назад, тимлид несколько месяцев назад.&lt;br&gt;AAA: Сегодня нам скинули скриншот чата, где люди хвалят друг-друга, а Слак-бот им недвусмысленно объясняет, чья команда реально была лучшей.&lt;br&gt;AAA: Само-собой с фоткой Саши, жабкой и осьминожкой."}' title="Поделиться цитатой">
#           <svg xmlns="http://www.w3.org/2000/svg" width="20" height="16" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#             <path d="M9 .116l3.942 3.942-.884.884-2.433-2.433V12h-1.25V2.509L5.942 4.942l-.884-.884L9 .116zM1.625 9H.375v6.625h17.25V9h-1.25v5.375H1.625V9z"/>
#           </svg>
#         </div>
#
#       </footer>
#       </div>
# </article>                                      </section>
#
#
#
#   <div class="pager">
#                 <span class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M10 2L4.5 7l5.5 5M5 7h9M1 0v14" stroke="currentColor" stroke-width="1"/></svg></span><span class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><title="Свежее"/><path d="M8 2L3 7l5 5M3 7h9" stroke="currentColor" stroke-width="1"/></svg></span><input type="number" name="page" class="pager__input" pattern="[0-9]+" data-page numeric="integer" min="1" max="3434" data-path="index" value="3434" autocomplete="off"><a href="/index/3433" class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><title="Начало"/><path d="M6 2l5 5-5 5M2 7h9" stroke="currentColor" stroke-width="1"/></svg></a><a href="/index/1" class="pager__item"><svg width="14" height="14" viewBox="0 0 14 14" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M4 2l5 5-5 5M0 7h9M13 0v14" stroke="currentColor" stroke-width="1"/></svg></a>          </form>
#   </div>
# <div class="sections desktop bottom">
#       <ul class="sections__list">
#       <li class="sections__item">
#         <a class="sections__link active" href="/">новые</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/best">лучшие</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/random">случайные</a>
#       </li>
#       <li class="sections__item">
#         <a class="sections__link " href="/byrating">по рейтингу</a>
#       </li>
#     </ul>
#   </div>
#     </main>
#           <aside class="columns__aside">
#         <div class="columns__aside_wrap">
#             <!--AdFox START-->
#   <!--MarTi-->
#   <!--Площадка: Bash.im / * / *-->
#   <!--Тип баннера: Side-->
#   <!--Расположение: <верх страницы>-->
#   <div id="adfox_side1"></div>
#   <script async src="data:text/javascript,%28function%28w%2Cn%29%7Bw%5Bn%5D%3Dw%5Bn%5D%7C%7C%5B%5D%3Bw%5Bn%5D.push%28%7BownerId%3A%20254948%2C%20containerId%3A%20%22adfox_side1%22%2C%20params%3A%20%7Bpp%3A%20%27g%27%2C%20ps%3A%20%27cwie%27%2C%20p2%3A%20%27fvyf%27%2C%20puid1%3A%20%27%27%7D%2C%20onLoad%3A%20function%28%29%7Bwindow.addEventListener%28%27scroll%27%2C%20function%20handleScroll%28%29%7B%0A%20%20%20%20%20%20%20%20var%20reload%20%3D%20setTimeout%28function%28%29%7B%0A%20%20%20%20%20%20%20%20%20%20if%20%28%21window.isLoading%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%2F%2F%20console.log%28%27aside%20reload%27%29%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20window.Ya.adfoxCode.reload%28%27adfox_side1%27%29%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20clearTimeout%28reload%29%3B%0A%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%7D%2C%2020000%29%3B%0A%20%20%20%20%20%20%20%20window.removeEventListener%28%27scroll%27%2C%20handleScroll%29%3B%0A%20%20%20%20%20%20%7D%29%7D%7D%29%3B%7D%29%28window%2C%20%22adfoxAsyncParams%22%29%3B"></script>        </div>
#       </aside>
#       </div>
#   <footer class="footer">
#     <nav class="footer__nav">
#       <a href="/faq" class="footer__nav_link ">
#         О сайте
#       </a>
#       <a href="/webmaster" class="footer__nav_link ">
#         Вебмастеру
#       </a>
#       <a href="/rss" class="footer__nav_link">RSS</a>
#       <a href="/rss/comics.xml" class="footer__nav_link">RSS комиксов</a>
#     </nav>
#     <div class="footer__legal">
#       <p class="footer__legal_para">
# 	         Идея проекта &copy; bash.org. Реализация и плюшки &copy; 2004–2021, команда bash.im. Использование сайта подразумевает согласие с&nbsp;<a href="/eula">пользовательским соглашением</a>. <b>18+</b>
#       </p>
#       <p class="footer__legal_para">
#         Если&nbsp;что, пишите в&nbsp;техподдержку: <a href="mailto:support@bash.im">support@bash.im</a>
#       </p>
#     </div>
#     <div class="footer__badges">
#   <div class="footer__badges_item">
#     <!--LiveInternet logo-->
#     <a href="//www.liveinternet.ru/click" target="_blank">
#       <img src="//counter.yadro.ru/logo?15.1" title="LiveInternet: показано число просмотров за 24 часа, посетителей за 24 часа и за сегодня" alt="" border="0" width="88" height="31">
#     </a>
#     <!--/LiveInternet-->
#   </div>
#   <div class="footer__badges_item">
#       <!-- Rating@Mail.ru logo -->
#       <a href="https://top.mail.ru/jump?from=901403">
#         <img src="//top-fwz1.mail.ru/counter?id=901403;t=464;l=1" style="border:0;" height="31" width="88" alt="Рейтинг@Mail.ru">
#       </a>
#       <!-- //Rating@Mail.ru logo -->
#   </div>
#   <div class="footer__badges_item">
#     <a href="https://www.yandex.ru/cy?base=0&host=bash.im">
#       <img src="https://www.yandex.ru/cycounter?bash.im" width="88" height="31" alt="Индекс Цитирования Яndex" border="0">
#     </a>
#   </div>
# </div></footer>        <script>
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-3271837-1']);
#   _gaq.push(['_setDomainName', 'bash.im']);
#   _gaq.push(['_setAllowLinker', true]);
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var s = document.getElementsByTagName('script')[0];
#     var ga = document.createElement('script');
#     ga.type = 'text/javascript';
#     ga.async = true;
#     ga.src = '//google-analytics.com/ga.js'
#     s.parentNode.insertBefore(ga, s);
#   })();
# </script>
# <!-- Rating@Mail.ru counter -->
# <script>
#   var _tmr = window._tmr || (window._tmr = []);
#   _tmr.push({
#     id: '901403',
#     type: 'pageView',
#     start: (new Date()).getTime()
#   });
#   (function(d, w, id) {
#     if (d.getElementById(id)) return;
#     var ts = d.createElement('script');
#     ts.async = true;
#     ts.id = id;
#     ts.src = '//top-fwz1.mail.ru/js/code.js';
#     var f = function() {
#       var s = d.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(ts, s);
#     };
#     if (w.opera == '[object Opera]') {
#       d.addEventListener('DOMContentLoaded', f, false);
#     } else {
#       f();
#     }
#   })(document, window, 'topmailru-code');
# </script>
# <noscript>
#   <div>
#     <img src="//top-fwz1.mail.ru/counter?id=901403;js=na" style="border:0;position:absolute;left:-9999px;" alt="" />
#   </div>
# </noscript>
# <!-- //Rating@Mail.ru counter -->
#
#   <!--LiveInternet counter-->
#   <script>
#     new Image().src = '//counter.yadro.ru/hit?r' +
#         escape(document.referrer) + ((typeof(screen) == 'undefined') ? '' :
#         ';s' + screen.width + '*' + screen.height + '*' + (screen.colorDepth ?
#         screen.colorDepth : screen.pixelDepth)) + ';u' + escape(document.URL) +
#         ';h' + escape(document.title.substring(0, 150)) + ';' + Math.random();
#   </script>
#   <!--/LiveInternet-->
#
# <script type="text/javascript">
#   var currentTheme = localStorage.getItem("theme") || "light";
# </script>
#
#
#     <!-- Yandex.Metrika counter non-mobile -->
# 	<script type="text/javascript" >
# 	   (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
# 	   m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# 	   (window, document, "script", "https://cdn.jsdelivr.net/npm/yandex-metrica-watch/tag.js", "ym");
#
# 	   ym(18640348, "init", {
# 		clickmap:true,
# 		trackLinks:true,
# 		accurateTrackBounce:true
# 	   });
#
#            ym(18640348, "params", { theme: currentTheme });
#
# 		window.addEventListener('load', function() {
# 		  setTimeout(function () {
# 		    if (typeof web3 !== 'undefined') {
# 		      ym(18640348, 'reachGoal', 'w3');
# 		    }
# 		  }, 5000);
# 		});
#
# 	</script>
# 	<noscript><div><img src="https://mc.yandex.ru/watch/18640348" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#     <!-- /Yandex.Metrika counter -->
#
#     <script src="/3.0/bor.js?54e9492e3e49b12224457e7671125ac4" async data-turbolinks-eval="false"></script>
#   <script>
#   var badges = [
#     {
#       'name': 'index',
#       'timestamp': 1638606278,
#       'counter': 85837,
#       'id': 467994
#     },
#     {
#       'name': 'strips',
#       'timestamp': 1638606278,
#       'counter': 1944,
#       'id': 20210324
#     },
#     {
#       'name': 'abyssbest',
#       'timestamp': 1638606278,
#       'counter': 11543,
#       'id': 310975
#     },
#   ];
#   var localBadges = JSON.parse(localStorage.getItem('badges'));
#   if (localBadges != null) {
#     localBadges.forEach(function(item, index) {
#       var delta = badges[index].counter - item.counter;
#       if (!isNaN(parseFloat(delta)) && delta > 0) {
#         if ('index' === badges[index].name) {
#             localBadges[index] = badges[index];
#         } else {
#             var elem = document.querySelector('[data-badge="' + item.name + '"]');
#             if (elem != null) {
#               elem.innerText = delta <= 10 ? delta : '9+';
#               setTimeout(function(){
#                 elem.classList.add('active');
#               }, 50);
#             }
#         }
#       }
#     });
#     localStorage.setItem('badges', JSON.stringify(localBadges));
#   } else {
#     localStorage.setItem('badges', JSON.stringify(badges));
#   }
# </script>
#   <div class="nav mobile">
#   <div class="nav__wrap">
#     <a class="nav__item about " href="/faq">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M26 19a6 6 0 1 1-12 0 6 6 0 0 1 12 0zm1 0a7 7 0 1 1-14 0 7 7 0 0 1 14 0zm-6-3a1 1 0 1 1-2 0 1 1 0 0 1 2 0zm-1 1.875c.345 0 .625.28.625.625v4a.625.625 0 1 1-1.25 0v-4c0-.345.28-.625.625-.625z"></path>
#       </svg>
#       <span class="nav__item_name">О проекте</span>
#       </a>
#       <div class="nav__item theme">
#         <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#           <g class="moon">
#             <path d="M24.295 22.652c-.175-.094-.828.06-1.11.06-3.785 0-6.854-2.931-6.854-6.644 0-.403 0-.736.126-1.12a.13.13 0 0 0 .007-.049c-.007-.12-.066-.225-.166-.104a6.683 6.683 0 0 0-.345.446c-.578.834-.945 2.006-.945 3.206 0 3.073 2.54 5.564 5.672 5.564 1.651 0 3.26-.796 3.615-1.359zm.671-1.208c-.437.183-.776.28-1.782.28-3.228 0-5.844-2.568-5.844-5.735 0-.91.113-1.473.244-1.993l.002-.007.05-.194.013-.052c.04-.155.08-.31.119-.474.034-.146-.076-.285-.228-.268a2.1 2.1 0 0 0-.467.113 2.703 2.703 0 0 0-.34.15c-1.388.73-2.733 2.817-2.733 5.183C14 22.067 16.99 25 20.68 25c2.49 0 4.468-1.222 5.114-2.83l.021-.053a3.162 3.162 0 0 0 .183-.742c.02-.17-.15-.289-.312-.228a10.53 10.53 0 0 0-.547.224l-.145.061-.027.012z"></path>
#           </g>
#           <g class="sun">
#             <path d="M20 13a.5.5 0 0 1-.5-.5v-1a.5.5 0 0 1 1 0v1a.5.5 0 0 1-.5.5zM15.757 14.757a.5.5 0 0 1-.707 0l-.707-.707a.5.5 0 1 1 .707-.707l.707.707a.5.5 0 0 1 0 .707zM25.657 13.343a.5.5 0 0 1 0 .707l-.707.707a.5.5 0 1 1-.707-.707l.707-.707a.5.5 0 0 1 .707 0zM15.757 23.243a.5.5 0 0 1 0 .707l-.707.707a.5.5 0 0 1-.707-.707l.707-.707a.5.5 0 0 1 .707 0zM28 19a.5.5 0 0 1-.5.5h-1a.5.5 0 1 1 0-1h1a.5.5 0 0 1 .5.5zM14 19a.5.5 0 0 1-.5.5h-1a.5.5 0 0 1 0-1h1a.5.5 0 0 1 .5.5zM25.657 24.657a.5.5 0 0 1-.707 0l-.707-.707a.5.5 0 1 1 .707-.707l.707.707a.5.5 0 0 1 0 .707zM19.5 26.5a.5.5 0 0 0 1 0v-1a.5.5 0 1 0-1 0v1z"></path>
#             <path d="M24 19a4 4 0 1 1-8 0 4 4 0 0 1 8 0zm-1 0a3 3 0 1 1-6 0 3 3 0 0 1 6 0z"></path>
#           </g>
#       </svg>
#       <span class="nav__item_name">Тема</span>
#     </div>
#     <a class="nav__item active" href="/">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M27.618 18.107l-7.31-5.743L13 18.107l.618.786 1.19-.936V25.5h11v-7.543l1.192.936.618-.786zm-2.81-.935l-4.5-3.536-4.5 3.536V24.5h9v-7.328z"></path>
#       </svg>
#       <span class="nav__item_name">Новые</span>
#       <span class="nav__item_badge" data-badge="index"></span>
#     </a>
#     <a class="nav__item " href="/abyss/">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M25.849 15.448A.786.786 0 0 0 26 15c0-1.105-2.686-2-6-2s-6 .895-6 2c0 .16.056.315.162.464L18 21.642v4.727l4-2.667v-2.06l3.852-6.194h-.003zm-1.854 1.044c-1.061.316-2.46.508-3.995.508-1.534 0-2.934-.192-3.994-.508L19 21.358V24.5l2-1.333v-1.809l2.995-4.866zM24.844 15c0 .552-2.16 1-4.825 1-2.664 0-4.824-.448-4.824-1s2.16-1 4.825-1c2.664 0 4.824.448 4.824 1z"></path>
#       </svg>
#       <span class="nav__item_name">Бездна</span>
#     </a>
#     <a class="nav__item " href="/strips">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M19.5 19h-3v-1h3v1zM23.5 19h-3v-1h3v1z"></path>
#         <path d="M17 15h6l3-3v11a3 3 0 0 1-3 3h-6a3 3 0 0 1-3-3V12l3 3zm8-.586V23a2 2 0 0 1-2 2h-6a2 2 0 0 1-2-2v-8.586L16.586 16h6.828L25 14.414z"></path>
#       </svg>
#       <span class="nav__item_name">Комиксы</span>
#       <span class="nav__item_badge" data-badge="strips"></span>
#     </a>
#     <a class="nav__item " href="/search">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M25 18a5 5 0 1 1-10 0 5 5 0 0 1 10 0zm-1.31 4.731a6 6 0 1 1 .734-.679l2.446 2.608-.73.684-2.45-2.613z"></path>
#       </svg>
#       <span class="nav__item_name">Поиск</span>
#     </a>
#     <a class="nav__item " href="/add">
#       <svg class="nav__item_icon" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 40 30" fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" aria-hidden="true">
#         <path d="M19.5 18.5V24h1v-5.5H26v-1h-5.5V12h-1v5.5H14v1h5.5z"></path>
#       </svg>
#       <span class="nav__item_name">Добавить</span>
#     </a>
#   </div>
# </div></body>
# </html>

# %% [markdown]
# Как вы видите, аргументы декорируемой функции передаются функции-обёртке, после чего с ними можно делать что угодно. Можно изменять аргументы и затем передавать их декорируемой функции, а можно оставить их как есть или вовсе забыть про них и передать что-нибудь совсем другое. То же касается возвращаемого из декорируемой функции значения, с ним тоже можно делать что угодно.

# %% [markdown]
# Декораторы с аргументами

# %%
def benchmark(iters):
    def actual_decorator(func):
        import time
        
        def wrapper(*args, **kwargs):
            total = 0
            for i in range(iters):
                start = time.time()
                return_value = func(*args, **kwargs)
                end = time.time()
                total = total + (end-start)
            print('[*] Среднее время выполнения: {} секунд.'.format(total/iters))
            return return_value

        return wrapper
    return actual_decorator


@benchmark(iters=10)
def fetch_webpage(url):
    import requests
    webpage = requests.get(url)
    return webpage.text

webpage = fetch_webpage('http://info.cern.ch')
print(webpage)
# Out:
# [*] Среднее время выполнения: 0.12411386966705322 секунд.
# <html><head></head><body><header>
# <title>http://info.cern.ch</title>
# </header>
#
# <h1>http://info.cern.ch - home of the first website</h1>
# <p>From here you can:</p>
# <ul>
# <li><a href="http://info.cern.ch/hypertext/WWW/TheProject.html">Browse the first website</a></li>
# <li><a href="http://line-mode.cern.ch/www/hypertext/WWW/TheProject.html">Browse the first website using the line-mode browser simulator</a></li>
# <li><a href="http://home.web.cern.ch/topics/birth-web">Learn about the birth of the web</a></li>
# <li><a href="http://home.web.cern.ch/about">Learn about CERN, the physics laboratory where the web was born</a></li>
# </ul>
# </body></html>

# %% [markdown]
# Декоратор принимает функцию в качестве аргумента и возвращает функцию.

# %% [markdown]
# Исполозать кешер в качестве декораторов

# %%
def memoize_func(f):
    memo = dict()
    def func(*args):
        print(f'Run with args={args}, memo={memo}')
        if args not in memo:
            memo[args] = f(*args)
        return memo[args]

    return func

# %%
def benchmark(func):
    import time
    
    def wrapper(*args, **kwargs):
        start = time.time()
        return_value = func(*args, **kwargs)
        end = time.time()
        print('[*] Время выполнения: {} секунд.'.format(end-start))
        return return_value
    return wrapper
@memoize_func1
@memoize_func2
def func(a, b):
    print(f'    Run func({a}, {b})')
    return a ** b

# %%
func(1,9)
# Out:
# Run with args=(1, 9), memo={}
#     Run func(1, 9)
# 1

# %%
func(1,9)
# Out:
# Run with args=(1, 9), memo={(1, 9): 1}
# 1

# %%
func(1,9)
# Out:
# Run with args=(1, 9), memo={(1, 9): 1}
# 1

# %%
func(2,2)
# Out:
# Run with args=(2, 2), memo={(1, 9): 1}
#     Run func(2, 2)
# 4

# %%
func(2,2)
# Out:
# Run with args=(2, 2), memo={(1, 9): 1, (2, 2): 4}
# 4

# %%
def bread(func):
    def wrapper():
        print ("</------\>")
        func()
        print ("<\______/>")
    return wrapper
 
def ingredients(func):
    def wrapper():
        print ("#помидоры#")
        func()
        print ("~салат~")
    return wrapper
 
def sandwich(food="--ветчина--"):
    print (food)
 
sandwich()
# Out:
# --ветчина--

# %%
sandwich = bread(ingredients(sandwich))

# %%
sandwich()
# Out:
# </------\>
# #помидоры#
# --ветчина--
# ~салат~
# <\______/>

# %%
@bread
@ingredients
def sandwich(food="--ветчина--"):
    print (food)

# %%
sandwich()
# Out:
# </------\>
# #помидоры#
# --ветчина--
# ~салат~
# <\______/>

# %%
Следует помнить о том, что порядок декорирования ВАЖЕН:

# %%
@ingredients

@bread

def sandwich(food="--ветчина--"):
    print (food)
 
sandwich()
# Out:
# #помидоры#
# </------\>
# --ветчина--
# <\______/>
# ~салат~

# %% [markdown]
# Декораторы несколько замедляют вызов функции, не забывайте об этом.
# Вы не можете «раздекорировать» функцию. Безусловно, существуют трюки, позволяющие создать декоратор, который можно отсоединить от функции, но это плохая практика. Правильней будет запомнить, что если функция декорирована — это не отменить.
# Декораторы оборачивают функции, что может затруднить отладку.

# %%
https://tirinox.ru/useful-decorators/

# %% [markdown]
# ###  Виртуальное окружение

# %% [markdown]
# Что такое виртуальное окружение и зачем оно нужно?

# %% [markdown]
# При разработке Python-приложений или использовании решений на Python, созданных другими разработчиками, может возникнуть ряд проблем, связанных с использованием библиотек различных версий. Рассмотрим их более подробно.

# %% [markdown]
# Во-первых: различные приложения могут использовать одну и туже библиотеку, но при этом требуемые версии могут отличаться.

# %% [markdown]
# Во-вторых: может возникнуть необходимость в том, чтобы запретить вносить изменения в приложение на уровне библиотек, т.е. вы установили приложение и хотите, чтобы оно работало независимо от того обновляются у вас библиотеки или нет. Как вы понимаете, если оно будет использовать библиотеки из глобального хранилища (/usr/lib/pythonXX/site-packages), то, со временем, могут возникнуть проблемы.

# %% [markdown]
# В-третьих: у вас просто может не быть доступа к каталогу /usr/lib/pythonXX/site-packages.

# %% [markdown]
# Для решения данных вопросов используется подход, основанный на построении виртуальных окружений – своего рода песочниц, в рамках которых запускается приложение со своими библиотеками, обновление и изменение которых не затронет другие приложение, использующие те же библиотеки.

# %% [markdown]
# ПО позволяющее создавать виртуальное окружение в Python

# %% [markdown]
# virtualenv
#
# Это, наверное, одни из самых популярных инструментов, позволяющих создавать виртуальные окружения. Он прост в установке и использовании. В сети довольно много руководств по virtualenv, самые интересные, на наш взгляд, будут собраны в конце урока в разделе “Полезные ссылки”. В общем, этот инструмент нужно обязательно освоить, как минимум, потому что описание развертывания и использования многих систем, созданных с использованием Python, включает в себя процесс создания виртуального окружения с помощью virtualenv.
#
# pyenv
#
# Инструмент для изоляции версий Python. Чаще всего применяется, когда на одной машине вам нужно иметь несколько версий интерпретатора для тестирования на них разрабатываемого вами ПО.
#
# virtualenvwrapper
#
# Virtualenvwrapper – это обертка для virtualenv позволяющая хранить все изолированные окружения в одном месте, создавать их, копировать и удалять. Предоставляет удобный способ переключения между окружениями и возможность расширять функционал за счет plug-in’ов.
#
# Существуют ещё инструменты и plug-in’ы, выполняющие работу по изоляции частей системы Python, но мы их не будем рассматривать.
#
# Инструменты, входящие в стандартную библиотеку Python.
#
# venv
#
# Этот модуль появился в Python3 и не может быть использован для решения задачи изоляции в Python2. По своему функционалу очень похож на virtualenv. Если вы работаете с третьим Python, то можете смело использовать данный инструмент.

# %% [markdown]
# virtualenv

# %% [markdown]
# Будем рассматривать работу с virtualenv в рамках операционной системы Linux. Для Windows все будет очень похоже, за исключением моментов, связанных со спецификой этой ОС: названия и расположение каталогов, запуск скриптов оболочки и т.п.

# %% [markdown]
# Установка virtualenv
# Virtualenv можно установить с использованием менеджера pip (ссылка на статью), либо скачать исходные коды проекта и установить приложение вручную.

# %% [markdown]
# Установка с использованием pip.

# %% [markdown]
# Для установки virtualenv откройте консоль и введите следующую команду:
#
# > pip install virtualenv

# %% [markdown]
# Установка из исходного кода проекта.
#
# В этом случае, вам нужно будет выполнить чуть большее количество действий.
#
# Введите в консоли следующий набор команд:
#
# > curl -O https://pypi.python.org/packages/source/v/virtualenv/virtualenv-X.X.tar.gz
# > tar xvfz virtualenv-X.X.tar.gz
# > cd virtualenv-X.X
# >  [sudo] python setup.py install

# %%
> virtualenv PRG1

# %% [markdown]
# PRG1 в данном случае – это имя окружения.

# %% [markdown]
# После выполнения данной команды, в текущем каталоге будет создан новый каталог с именем PRG1. Разберем более подробно его содержимое.

# %% [markdown]
# RPG1/bin/ – содержит скрипты для активации/деактивации окружения, интерпретатор Python, используемый в рамках данного окружения, менеджер pip и ещё несколько инструментов, обеспечивающих работу с пакетами Python. В Windows, это каталог PRG1\Scripts

# %% [markdown]
# PRG1/include/ и PRG1/lib/ – каталоги, содержащие библиотечные файлы окружения. Новые пакеты будут установлены в каталог PRG1/lib/pythonX.X/site-packages/.

# %% [markdown]
# Для активации виртуального окружения воспользуйтесь командой (для Linux):

# %% [markdown]
# > source PRG1/bin/activate

# %% [markdown]
# для Windows команда будет выглядеть так:

# %% [markdown]
# > PRG1\Scripts\activate.bat

# %% [markdown]
# Если команда выполнилась успешно, то вы увидите, что перед приглашением в командной строке появилась дополнительная надпись, совпадающая с именем виртуального окружения.

# %% [markdown]
# При этом в переменную окружения PATH, в самое начало, будет добавлен путь до директории bin, созданного каталога RPG1.

# %% [markdown]
# Деактивация виртуального окружения

# %% [markdown]
# Для деактивации виртуального окружения (выхода из него), введите команду deactivate для Linux или deactivate.bat, если вы работаете в Windows.

# %% [markdown]
# Устанавливать venv не нужно, т.к. он входит в стандартную библиотеку Python. Т.е. если вы установили себе Python, то venv у вас уже есть. Помните, что venv работает только в Python3!

# %% [markdown]
# >source PRG2/bin/activate

# %% [markdown]
# >PRG2\Scripts\activate.bat

# %% [markdown]
# https://python-scripts.com/virtualenv

# %% [markdown]
# ###  Исключения

# %% [markdown]
# ### 1 Обработка исключений через try/except/finally/else.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Допустим, вы пытаетесь открыть файл, но вы ввели неверный путь, или вы хотите узнать информацию у пользователей и они пишут какую-то бессмыслицу. Вы не хотите, чтобы ваша программа крэшилась, по-этому вы выполняете обработку исключений. В Пайтоне, конструкция практически всегда обернута в то, что называется try/except.

# %% [markdown]
# Обратите внимание на то, что ошибка и исключение – два разных слова, описывающие одно и то же, в контексте обработки исключений.

# %% [markdown]
# ###### Базовые типы исключений;
#
# ###### Обработка исключений при помощи try/except;
#
# ###### Узнаем, как работает try/except/finally;
#
# ###### Выясним, как работает оператор else совместно с try/except;

# %% [markdown]
# ###### Базовые типы исключений;
# Exception – то, на чем фактически строятся все остальные ошибки;
#
# AttributeError – возникает, когда ссылка атрибута или присвоение не могут быть выполнены;
#
# IOError – возникает в том случае, когда операция I/O (такая как оператор вывода, встроенная функция open() или метод объекта-файла) не может быть выполнена, по связанной с I/O причине: «файл не найден», или «диск заполнен», иными словами.
#
# ImportError – возникает, когда оператор import не может найти определение модуля, или когда оператор не может найти имя файла, который должен быть импортирован;
#
# IndexError – возникает, когда индекс последовательности находится вне допустимого диапазона;
#
# KeyError – возникает, когда ключ сопоставления (dictionary key) не найден в наборе существующих ключей;
#
# KeyboardInterrupt – возникает, когда пользователь нажимает клавишу прерывания(обычно Delete или Ctrl+C);
#
# NameError – возникает, когда локальное или глобальное имя не найдено;
#
# OSError – возникает, когда функция получает связанную с системой ошибку;
#
# SyntaxError — возникает, когда синтаксическая ошибка встречается синтаксическим анализатором;
#
# TypeError – возникает, когда операция или функция применяется к объекту несоответствующего типа. Связанное значение представляет собой строку, в которой приводятся подробные сведения о несоответствии типов;
#
# ValueError – возникает, когда встроенная операция или функция получают аргумент, тип которого правильный, но неправильно значение, и ситуация не может описано более точно, как при возникновении IndexError;
#
# ZeroDivisionError – возникает, когда второй аргумент операции division или modulo равен нулю;

# %%
BaseException
 +-- SystemExit
 +-- KeyboardInterrupt
 +-- GeneratorExit
 +-- Exception
      +-- StopIteration
      +-- StandardError
      |    +-- BufferError
      |    +-- ArithmeticError
      |    |    +-- FloatingPointError
      |    |    +-- OverflowError
      |    |    +-- ZeroDivisionError
      |    +-- AssertionError
      |    +-- AttributeError
      |    +-- EnvironmentError
      |    |    +-- IOError
      |    |    +-- OSError
      |    |         +-- WindowsError (Windows)
      |    |         +-- VMSError (VMS)
      |    +-- EOFError
      |    +-- ImportError
      |    +-- LookupError
      |    |    +-- IndexError
      |    |    +-- KeyError
      |    +-- MemoryError
      |    +-- NameError
      |    |    +-- UnboundLocalError
      |    +-- ReferenceError
      |    +-- RuntimeError
      |    |    +-- NotImplementedError
      |    +-- SyntaxError
      |    |    +-- IndentationError
      |    |         +-- TabError
      |    +-- SystemError
      |    +-- TypeError
      |    +-- ValueError
      |         +-- UnicodeError
      |              +-- UnicodeDecodeError
      |              +-- UnicodeEncodeError
      |              +-- UnicodeTranslateError
      +-- Warning
           +-- DeprecationWarning
           +-- PendingDeprecationWarning
           +-- RuntimeWarning
           +-- SyntaxWarning
           +-- UserWarning
           +-- FutureWarning
	   +-- ImportWarning
	   +-- UnicodeWarning
	   +-- BytesWarning

# %% [markdown]
# документация Пайтон  https://docs.python.org/2/library/exceptions.html

# %% [markdown]
# #### Обработка исключений в Пайтон – это просто!

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-325-bc757c3fda29> in <module>
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Так же может быть и такая ошибка (зависит от вашего интерпритатора)

# %% [markdown]
# `
# Traceback (most recent call last):
#     File "<string>", line 1, in <fragment>
# ZeroDivisionError: integer division or modulo by zero
# `

# %%
try:
    1 / 0
except ZeroDivisionError:
    print("Ты что?! На ноль делить нельзя!! ")
# Out:
# Ты что?! На ноль делить нельзя!!

# %% [markdown]
# Таким образом, базовая конструкция выглядит так:

# %%
try:
    инструкции
except [Тип_исключения]:
    инструкции

# %% [markdown]
# С помощью оператора **as** мы можем передать всю информацию об исключении в переменную, которую затем можно использовать в блоке except:

# %%
try:
    a = 100
    b = 0
    c = a / b
except ZeroDivisionError as e:
    print(e)

# %%
try:
    number = int(input("Введите число: "))
    print("Введенное число:", number)
except ValueError as e:
    print("Сведения об исключении", e)
print("Завершение программы")
# Out:
# Введите число: 2323
# Введенное число: 2323
# Завершение программы

# %% [markdown]
# ### «Голое» исключение

# %%
try:
    1 / 0
except:
    print("какая-то ошибка")
# Out:
# какая-то ошибка

# %% [markdown]
# На жаргоне Пайтона, это известно как голое исключение, что означает, что будут найдены вообще все исключения.
#
# Причина, по которой так делать не рекомендуется, заключается в том, что вы не узнаете, что именно за исключение вы выловите. Когда у вас возникло что-то в духе ZeroDivisionError, вы хотите выявить фрагмент, в котором происходит деление на ноль. В коде, написанном выше, вы не можете указать, что именно вам нужно выявить.
#
# Посмотрим еще несколько примеров:

# %%
my_dict = {"a":1, "b":2, "c":3}
 
try:
    value = my_dict["d"]
except KeyError:
    print("Такого ключа нет")
# Out:
# Такого ключа нет

# %% [markdown]
# мы создали словарь из трех элементов. После этого, мы попытались открыть доступ ключу, которого в словаре нет.

# %%
my_list = ['1', '2', '3', '4', '5']
 
try:
    my_list['df']
except IndexError:
    print("Этот индекс не находится в списке!!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-335-6fcdc4c8c3c5> in <module>
#       2
#       3 try:
# ----> 4     my_list['df']
#       5 except IndexError:
#       6     print("Этот индекс не находится в списке!!")
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# Мы попытались взять шестой объект из индекса, забыв про нумерацию питона.

# %% [markdown]
# Можно выявить несколько ошибок за раз при помощи одного оператора. Для этого существует несколько различных способов. Давайте посмотрим:

# %%
my_dict = {"a":1, "b":2, "c":3}
 
try:
    value = my_dict['sdsd']
except IndexError:
    print("This index does not exist!")
except KeyError:
    print("This key is not in the dictionary!")
except:
    print("Some other error occurred!")
# Out:
# This key is not in the dictionary!

# %% [markdown]
# И второй способ:

# %%
try:
    value = my_dict["d"]
except (IndexError, KeyError):
    print("An IndexError or KeyError occurred!")
# Out:
# An IndexError or KeyError occurred!

# %% [markdown]
# Проблема данного метода в том, что трудно сказать какая именно ошибка произошла, так что предыдущий пример, мы рекомендуем больше чем этот. Зачастую, когда происходит ошибка, вам нужно уведомить пользователя, при помощи сообщения.

# %% [markdown]
# ### finally!!!

# %%
В зависимости от сложности данной ошибки, вам может понадобиться выйти из программы. Иногда вам может понадобиться выполнить очистку, перед выходом из программы. Например, мы открыли соединение с базой данных, и нужно будет закрыть его, перед выходом из программы, или вы можете закончить с открытым соединением. Другой пример – закрытие дескриптора файла, к которому вы обращаетесь. Теперь нам нужно научиться убирать за собой. Это очень просто, если использовать оператор finally.

Так же оператор try/except также имеет пункт else. Он работает только в том случае, если в вашем коде нет ни единой ошибки.

# %%
try:
    исполяем какой-то код
except Exception as e:
    обработка исключения
else:
    код, который будет исполнен в случае, когда не возникает исключения
finally:
    код, который гарантированно будет исполнен последним (всегда исполняется)

# %%
try:
    number = float(input("Введите число: "))
    print("Введенное число:", number)
except ValueError:
    print("Не удалось преобразовать число")
finally:
    print("Блок try завершил выполнение")
print("Завершение программы")
# Out:
# Введите число: fdf
# Не удалось преобразовать число
# Блок try завершил выполнение
# Завершение программы

# %% [markdown]
# Иными словами, finally выполняет блок инструкций в любом случае, было ли исключение, или нет. А инструкция else выполняется в том случае, если исключения не было.

# %% [markdown]
# можно также вписать код exit в конце оператора finally.

# %%
my_dict = {"a":1, "b":2, "c":3}
 
try:
    value = my_dict["a"]
except KeyError:
    print("KeyError ошибка!")
else:
    print("Нет ошибок!")
finally:
    print("Запущен финальный код!")
# Out:
# Нет ошибок!
# Запущен финальный код!

# %% [markdown]
# Единственное полезное применение оператора else, это когда вы хотите запустить вторую часть кода, в которой может быть ошибка. Конечно, если ошибка возникает в else, то она не будет поймана.

# %% [markdown]
# ### Еще несколько примеров

# %% [markdown]
# В блок except можно поместить обработку.

# %%
try:
    a = 100
    b = 0
    c = a / b
except ZeroDivisionError as e:
    c = -1

# %%
c
# Out:
# 100.0

# %% [markdown]
# Пускай у нас файл с данными в файловой системе и необходимо его прочитать. В этом случае сразу же всплывают несколько исключительных ситуаций, такие как: нет файла, файл битый; файл пустой (по заданию мы знаем, что в нем данные) и другие.
# Используя исключения, можно вот так решить эту задачу:

# %%
try:
    filepath = '1.txt'
    with open(filepath, 'r') as f:
        result = f.readlines()
    if not result:
        raise Exception("File is empty")

except IOError as e:
    result = []
    print(e)
except Exception as e:
    result = []
    print(e)

# %% [markdown]
# В данном вымышленном коде новый ход - перехват нескольких видов исключений. Когда исключение брошено, оно сравнивается сверху вниз с каждым типом, пока не найдено совпадение. Если совпадения нет, то исключение пойдет наверх по цепочке исполнения кода.
#
# Если обработка для разных типов исключений одинакова, то уменьшить количество кода становится не проблемой:
# (файлы 1,2,3)

# %%
try:
    filepath = '3.txt'
    with open(filepath, 'r') as f:
        result = f.readlines()
    if not result:
        raise Exception("файл пустой")
except (IOError, Exception) as e:
    print(e)

# %% [markdown]
# ### Вызов исключений

# %% [markdown]
# При работе с исключениями программист тратит большую часть времени на обработку, но при этом возникают ситуации, когда исключениями надо и бросать в других.
#
# На нашем сленге "бросить исключение" означает написать код, который при исполнении будет инициировать исключительную ситуацию.
#
# Например, функция, которая решает квадратное уравнение. Вы условились, что корни только вещественные, тогда в случае комплексных корней стоит бросить исключение.
#
# Чтобы бросить исключение необходимо воспользоваться raise

# %%
raise IOError("текст исключения")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-348-92141d998f3f> in <module>
# ----> 1 raise IOError("текст исключения")
#
# OSError: текст исключения

# %% [markdown]
# где IOError это класс исключения.

# %% [markdown]
# Самый простой пример работы с raise может выглядеть так.

# %%
try:
   raise Exception("Какое-то исключение")
except Exception as e:
   print("Exception exception " + str(e))
# Out:
# Exception exception Какое-то исключение

# %%
try:
    number1 = int(input("Введите первое число: "))
    number2 = int(input("Введите второе число: "))
    if number2 == 2:
        raise Exception("Второе число не должно быть равно 2")
    print("Результат деления двух чисел:", number1/number2)
except ValueError:
    print("Введены некорректные данные")
except Exception as e:
    print(e)
print("Завершение программы")

# %% [markdown]
# Задача 1. Напишите программу с классом Student, в котором есть три атрибута: name, groupNumber и age. По умолчанию name = Ivan, age = 18, groupNumber = 10A. Необходимо создать пять методов: getName, getAge, getGroupNumber, setNameAge, setGroupNumber. Метод getName нужен для получения данных об имени конкретного студента, метод getAge нужен для получения данных о возрасте конкретного студента, vетод setGroupNumberнужен для получения данных о номере группы конкретного студента. Метод SetNameAge позволяет изменить данные атрибутов установленных по умолчанию, метод setGroupNumber позволяет изменить номер группы установленный по умолчанию. В программе необходимо создать пять экземпляров класса Student, установить им разные имена, возраст и номер группы.

# %% [markdown]
# Задача 2. Напишите программу с классом Car. Создайте конструктор класса Car. Создайте атрибуты класса Car — color (цвет), type (тип), year (год). Напишите пять методов. Первый — запуск автомобиля, при его вызове выводится сообщение «Автомобиль заведен». Второй — отключение автомобиля — выводит сообщение «Автомобиль заглушен». Третий — присвоение автомобилю года выпуска. Четвертый метод — присвоение автомобилю типа. Пятый — присвоение автомобилю цвета.

# %% [markdown]
# Задача 3. Допишите функцию Nutrionm
